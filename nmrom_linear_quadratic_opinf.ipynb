# %%
import torch
import numpy as np

torch.set_default_dtype(torch.float64)

from torch.utils.tensorboard import SummaryWriter
import tqdm

from matplotlib import pyplot as plt

# %%
device = torch.device("cuda")

# %%
data1 = torch.tensor(np.load("mu_0.9.npy")).to(device)
data2 = torch.tensor(np.load("mu_0.95.npy")).to(device)
data3 = torch.tensor(np.load("mu_1.05.npy")).to(device)
data4 = torch.tensor(np.load("mu_1.1.npy")).to(device)

dt = 2 / 1500

X = torch.cat([data1, data2, data3, data4], axis=0)
x_ref = torch.mean(X, dim=0)
(S, N) = X.shape

X_test = torch.tensor(np.load("mu_1.0.npy")).to(device)

# %%
class NRBS(torch.nn.Module):
    def __init__(self, N, n, M1, M2, b):
        super(NRBS, self).__init__()

        mask = torch.zeros(N, M2)
        shift = (M2 - b) / (N - 1)

        for i in range(N):
            mask[i, int(np.ceil(shift*i)): int(np.ceil(shift*i)) + b] = 1

        new_mask = torch.zeros(N, M2)

        for idx in range(N):
            i = idx // 60
            j = idx % 60
            neighbours = [(i, j), (i-1, j), (i+1, j), (i, j+1), (i, j-1)]
            for neighbour_i, neighbour_j in neighbours:
              if (neighbour_i >=0 and neighbour_i < 60) and (neighbour_j >=0 and neighbour_j < 60):
                new_mask[idx] = new_mask[idx] + mask[60*neighbour_i + neighbour_j]

        new_mask[new_mask > 0] = 1

        self.register_buffer('mask', new_mask)


        self.encoder1 = torch.nn.Linear(N, M1)
        self.encoder2 = torch.nn.Linear(M1, n)

        self.decoder1 = torch.nn.Linear(n, M2)
        self.decoder2 = torch.nn.Linear(M2, N)

        torch.nn.init.kaiming_normal_(self.encoder1.weight)
        torch.nn.init.kaiming_normal_(self.encoder2.weight)
        torch.nn.init.kaiming_normal_(self.decoder1.weight)
        torch.nn.init.kaiming_normal_(self.decoder2.weight)

    def encode(self, x):
        x = self.encoder1(x)
        x = x * torch.sigmoid(x)
        x = self.encoder2(x)
        return x

    def decode(self, x):
        x = self.decoder1(x)
        x = x * torch.sigmoid(x)
        x = torch.matmul(x, (self.decoder2.weight * self.get_buffer('mask')).T) + self.decoder2.bias
        return x

    def forward(self, x):
        return self.decode(self.encode(x))

# %%
n = 20
nx = 60
ny = 60

nrbs = NRBS(N, n, 6728, 33730, 70).to(device)
nrbs = torch.load('models/shallow_mask_old.pth')

X_tilde = nrbs(X_test - x_ref) + x_ref
l_test = torch.sqrt(torch.sum((X_test - X_tilde) ** 2)) / torch.sqrt(
    torch.sum(X_test**2)
)
l_test
# Out:
# tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)

# %%
def u_hat_and_u_hat_dot(nrbs, u, u_ref, dt):
    with torch.no_grad():
        u_hat = nrbs.encode(u - u_ref)
        u_hat_dot = (u_hat[1:] - u_hat[:-1]) / dt
        u_hat = u_hat[1:]
    return u_hat, u_hat_dot

# %%
data1_hat, data1_hat_dot = u_hat_and_u_hat_dot(nrbs, data1, x_ref, dt)
data2_hat, data2_hat_dot = u_hat_and_u_hat_dot(nrbs, data2, x_ref, dt)
data3_hat, data3_hat_dot = u_hat_and_u_hat_dot(nrbs, data3, x_ref, dt)
data4_hat, data4_hat_dot = u_hat_and_u_hat_dot(nrbs, data4, x_ref, dt)

# %%
X_hat = torch.cat([data1_hat, data2_hat, data3_hat, data4_hat])
X_hat_dot = torch.cat([data1_hat_dot, data2_hat_dot, data3_hat_dot, data4_hat_dot])

X_hat_test, X_hat_dot_test = u_hat_and_u_hat_dot(nrbs, X_test, x_ref, dt)

(S, n) = X_hat.shape

# %%
X_hat = X_hat.detach().cpu().numpy()
X_hat_dot = X_hat_dot.detach().cpu().numpy()

X_hat_test = X_hat_test.detach().cpu().numpy()
X_hat_dot_test = X_hat_dot_test.detach().cpu().numpy()

# %%
D = np.zeros((S, n + n * n))
for i in range(S):
    D[i, 0:n] = X_hat[i]
    D[i, n:] = np.outer(X_hat[i], X_hat[i]).flatten()

# %%
res = np.linalg.lstsq(D, X_hat_dot, rcond=1e-11)
AH_red = res[0]
A_red = AH_red[0:n, :].T
H_red = AH_red[n:, :].T

# %%
def nr_solve(f, df, x, atol=1e-10, rtol=1e-8, max_itr=50, args=None):
    r = f(x, *args)
    r0_norm = np.linalg.norm(r)
    print("Itr = {:}, residual norm = {:.4E}".format(0, r0_norm))
    if (r0_norm < atol):
        return x
    for i in range(max_itr):
        x = np.linalg.solve(df(x, *args), -r) + x
        r = f(x, *args)
        print("Itr = {:}, residual norm = {:.4E}".format(i + 1, np.linalg.norm(r)))
        if (np.linalg.norm(r) < atol or np.linalg.norm(r) / r0_norm < rtol):
            return x
    raise Exception("solve failed")

# %%
# replace with NN: u_hat to u_hat_dot
def f(x, x_old, dt):
    s_dot = np.matmul(A_red, x) + np.matmul(H_red, np.outer(x, x).flatten())
    return x - x_old - dt * s_dot

def df(x, x_old, dt):
    return np.eye(n) - (A_red + 2 * np.matmul(H_red.reshape(n, n, n), x)) * dt

# %%
x_red = X_hat_test[1]
t = 0
sol = {t : x_red}
dt = 2 / 1500
dt_min = dt / 100
while t < 2:
    print('Time = {:}, dt = {:}'.format(t + dt, dt))
    try:
        x_red = nr_solve(f, df, x_red, args=(x_red, dt))
    except:
        dt = dt / 2
        if (dt < dt_min):
            raise Exception("dt is too small")
        continue
    t = t + dt
    sol[t] = x_red
# Out:
# Time = 0.0013333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6713E-02
# Itr = 1, residual norm = 3.8494E-04
# Itr = 2, residual norm = 5.6495E-08
# Itr = 3, residual norm = 2.7834E-15
# Time = 0.0026666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6572E-02
# Itr = 1, residual norm = 3.8635E-04
# Itr = 2, residual norm = 5.6919E-08
# Itr = 3, residual norm = 3.0361E-15
# Time = 0.004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6423E-02
# Itr = 1, residual norm = 3.8739E-04
# Itr = 2, residual norm = 5.7388E-08
# Itr = 3, residual norm = 3.0612E-15
# Time = 0.005333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6283E-02
# Itr = 1, residual norm = 3.8746E-04
# Itr = 2, residual norm = 5.8157E-08
# Itr = 3, residual norm = 3.3276E-15
# Time = 0.006666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6142E-02
# Itr = 1, residual norm = 3.8603E-04
# Itr = 2, residual norm = 5.9513E-08
# Itr = 3, residual norm = 4.0093E-15
# Time = 0.008, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6037E-02
# Itr = 1, residual norm = 3.8272E-04
# Itr = 2, residual norm = 6.2317E-08
# Itr = 3, residual norm = 5.1144E-15
# Time = 0.009333333333333334, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6038E-02
# Itr = 1, residual norm = 3.8541E-04
# Itr = 2, residual norm = 7.0799E-08
# Itr = 3, residual norm = 2.6855E-15
# Time = 0.010666666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6479E-02
# Itr = 1, residual norm = 4.6992E-04
# Itr = 2, residual norm = 1.0762E-07
# Itr = 3, residual norm = 3.1674E-15
# Time = 0.012000000000000002, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.8840E-02
# Itr = 1, residual norm = 9.8406E-04
# Itr = 2, residual norm = 3.6650E-07
# Itr = 3, residual norm = 4.4112E-14
# Time = 0.013333333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.9676E-02
# Itr = 1, residual norm = 3.0836E-03
# Itr = 2, residual norm = 3.9665E-06
# Itr = 3, residual norm = 4.1319E-12
# Time = 0.01466666666666667, dt = 0.0013333333333333333
# Itr = 0, residual norm = 9.8614E-02
# Itr = 1, residual norm = 1.1990E-02
# Itr = 2, residual norm = 8.0303E-05
# Itr = 3, residual norm = 1.2899E-09
# Itr = 4, residual norm = 2.4514E-15
# Time = 0.016000000000000004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 1.9904E-01
# Itr = 1, residual norm = 4.9089E-02
# Itr = 2, residual norm = 1.3301E-03
# Itr = 3, residual norm = 2.2947E-07
# Itr = 4, residual norm = 2.6743E-14
# Time = 0.017333333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.8923E-01
# Itr = 1, residual norm = 1.5184E-01
# Itr = 2, residual norm = 7.4946E-03
# Itr = 3, residual norm = 1.0402E-05
# Itr = 4, residual norm = 6.8290E-11
# Time = 0.018666666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.4740E-01
# Itr = 1, residual norm = 2.7113E-01
# Itr = 2, residual norm = 7.5360E-02
# Itr = 3, residual norm = 1.3399E-02
# Itr = 4, residual norm = 5.2006E-03
# Itr = 5, residual norm = 9.0518E-03
# Itr = 6, residual norm = 4.3521E-03
# Itr = 7, residual norm = 6.5824E-01
# Itr = 8, residual norm = 1.6565E-01
# Itr = 9, residual norm = 4.2529E-02
# Itr = 10, residual norm = 1.1842E-02
# Itr = 11, residual norm = 4.6764E-03
# Itr = 12, residual norm = 1.6504E-02
# Itr = 13, residual norm = 5.6004E-03
# Itr = 14, residual norm = 6.2464E-03
# Itr = 15, residual norm = 5.1304E-03
# Itr = 16, residual norm = 8.3796E-03
# Itr = 17, residual norm = 4.3511E-03
# Itr = 18, residual norm = 7.9145E-01
# Itr = 19, residual norm = 1.9895E-01
# Itr = 20, residual norm = 5.0849E-02
# Itr = 21, residual norm = 1.3900E-02
# Itr = 22, residual norm = 5.0553E-03
# Itr = 23, residual norm = 8.9966E-03
# Itr = 24, residual norm = 4.3502E-03
# Itr = 25, residual norm = 9.3778E-01
# Itr = 26, residual norm = 2.3554E-01
# Itr = 27, residual norm = 5.9991E-02
# Itr = 28, residual norm = 1.6169E-02
# Itr = 29, residual norm = 5.5277E-03
# Itr = 30, residual norm = 6.4596E-03
# Itr = 31, residual norm = 4.9334E-03
# Itr = 32, residual norm = 1.0343E-02
# Itr = 33, residual norm = 4.4590E-03
# Itr = 34, residual norm = 4.3663E-02
# Itr = 35, residual norm = 1.2122E-02
# Itr = 36, residual norm = 4.7237E-03
# Itr = 37, residual norm = 1.4734E-02
# Itr = 38, residual norm = 5.2240E-03
# Itr = 39, residual norm = 7.7627E-03
# Itr = 40, residual norm = 4.4081E-03
# Itr = 41, residual norm = 7.7177E-02
# Itr = 42, residual norm = 2.0445E-02
# Itr = 43, residual norm = 6.4908E-03
# Itr = 44, residual norm = 4.9088E-03
# Itr = 45, residual norm = 1.0688E-02
# Itr = 46, residual norm = 4.5024E-03
# Itr = 47, residual norm = 3.2228E-02
# Itr = 48, residual norm = 9.3126E-03
# Itr = 49, residual norm = 4.3646E-03
# Itr = 50, residual norm = 2.4433E-01
# Time = 0.018000000000000002, dt = 0.0006666666666666666
# Itr = 0, residual norm = 3.2370E-01
# Itr = 1, residual norm = 3.8664E-02
# Itr = 2, residual norm = 4.9221E-02
# Itr = 3, residual norm = 1.8054E+01
# Itr = 4, residual norm = 4.5250E+00
# Itr = 5, residual norm = 1.1458E+00
# Itr = 6, residual norm = 3.1910E-01
# Itr = 7, residual norm = 6.2818E-02
# Itr = 8, residual norm = 6.6701E-02
# Itr = 9, residual norm = 1.3341E+00
# Itr = 10, residual norm = 3.4569E-01
# Itr = 11, residual norm = 9.7728E-02
# Itr = 12, residual norm = 3.8969E-02
# Itr = 13, residual norm = 1.2680E-01
# Itr = 14, residual norm = 4.4579E-02
# Itr = 15, residual norm = 6.1164E-02
# Itr = 16, residual norm = 3.7759E-02
# Itr = 17, residual norm = 2.6250E-01
# Itr = 18, residual norm = 7.6193E-02
# Itr = 19, residual norm = 3.6480E-02
# Itr = 20, residual norm = 4.6450E+00
# Itr = 21, residual norm = 1.1704E+00
# Itr = 22, residual norm = 3.0200E-01
# Itr = 23, residual norm = 8.5849E-02
# Itr = 24, residual norm = 3.7267E-02
# Itr = 25, residual norm = 4.0416E-01
# Itr = 26, residual norm = 1.1104E-01
# Itr = 27, residual norm = 4.1303E-02
# Itr = 28, residual norm = 8.7122E-02
# Itr = 29, residual norm = 3.7417E-02
# Itr = 30, residual norm = 3.4689E-01
# Itr = 31, residual norm = 9.6891E-02
# Itr = 32, residual norm = 3.8804E-02
# Itr = 33, residual norm = 1.5712E-01
# Itr = 34, residual norm = 5.1126E-02
# Itr = 35, residual norm = 4.4398E-02
# Itr = 36, residual norm = 6.1676E-02
# Itr = 37, residual norm = 3.7635E-02
# Itr = 38, residual norm = 2.8844E-01
# Itr = 39, residual norm = 8.2526E-02
# Itr = 40, residual norm = 3.6919E-02
# Itr = 41, residual norm = 6.6666E-01
# Itr = 42, residual norm = 1.7629E-01
# Itr = 43, residual norm = 5.5544E-02
# Itr = 44, residual norm = 4.0305E-02
# Itr = 45, residual norm = 1.0421E-01
# Itr = 46, residual norm = 4.0043E-02
# Itr = 47, residual norm = 1.1028E-01
# Itr = 48, residual norm = 4.1157E-02
# Itr = 49, residual norm = 8.9162E-02
# Itr = 50, residual norm = 3.7674E-02
# Time = 0.01766666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.6185E-01
# Itr = 1, residual norm = 2.3796E-03
# Itr = 2, residual norm = 1.8942E-06
# Itr = 3, residual norm = 9.1393E-13
# Time = 0.018000000000000006, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8504E-01
# Itr = 1, residual norm = 3.3162E-03
# Itr = 2, residual norm = 5.6602E-06
# Itr = 3, residual norm = 6.3257E-12
# Time = 0.01833333333333334, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.1132E-01
# Itr = 1, residual norm = 4.2028E-03
# Itr = 2, residual norm = 7.7896E-06
# Itr = 3, residual norm = 1.0190E-11
# Time = 0.018666666666666675, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.7686E-01
# Itr = 1, residual norm = 1.3719E-02
# Itr = 2, residual norm = 7.2355E-05
# Itr = 3, residual norm = 2.1848E-09
# Time = 0.01900000000000001, dt = 0.0003333333333333333
# Itr = 0, residual norm = 3.4633E-01
# Itr = 1, residual norm = 6.9642E-02
# Itr = 2, residual norm = 1.4323E-03
# Itr = 3, residual norm = 3.3727E-07
# Itr = 4, residual norm = 3.1559E-14
# Time = 0.019333333333333345, dt = 0.0003333333333333333
# Itr = 0, residual norm = 8.9616E-01
# Itr = 1, residual norm = 1.8117E-01
# Itr = 2, residual norm = 3.0051E-03
# Itr = 3, residual norm = 1.0066E-06
# Itr = 4, residual norm = 3.0501E-13
# Time = 0.01966666666666668, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.5167E+00
# Itr = 1, residual norm = 1.1904E+00
# Itr = 2, residual norm = 1.1114E-01
# Itr = 3, residual norm = 1.6986E-03
# Itr = 4, residual norm = 5.0251E-07
# Itr = 5, residual norm = 5.6816E-14
# Time = 0.020000000000000014, dt = 0.0003333333333333333
# Itr = 0, residual norm = 3.0027E+00
# Itr = 1, residual norm = 2.6181E+00
# Itr = 2, residual norm = 9.2388E-01
# Itr = 3, residual norm = 1.6674E-01
# Itr = 4, residual norm = 2.1204E-03
# Itr = 5, residual norm = 1.8170E-06
# Itr = 6, residual norm = 5.9186E-13
# Time = 0.02033333333333335, dt = 0.0003333333333333333
# Itr = 0, residual norm = 6.8350E+00
# Itr = 1, residual norm = 4.4363E+01
# Itr = 2, residual norm = 1.8499E+01
# Itr = 3, residual norm = 2.3288E+01
# Itr = 4, residual norm = 1.5374E+02
# Itr = 5, residual norm = 3.5050E+01
# Itr = 6, residual norm = 1.3970E+01
# Itr = 7, residual norm = 2.6790E+01
# Itr = 8, residual norm = 6.9977E+00
# Itr = 9, residual norm = 1.0064E+00
# Itr = 10, residual norm = 3.1899E-02
# Itr = 11, residual norm = 4.2603E-05
# Itr = 12, residual norm = 7.8762E-11
# Time = 0.020666666666666684, dt = 0.0003333333333333333
# Itr = 0, residual norm = 3.0751E+01
# Itr = 1, residual norm = 2.8573E+01
# Itr = 2, residual norm = 1.8361E+01
# Itr = 3, residual norm = 5.5805E+01
# Itr = 4, residual norm = 2.0927E+01
# Itr = 5, residual norm = 4.1982E+01
# Itr = 6, residual norm = 1.6659E+01
# Itr = 7, residual norm = 3.2553E+01
# Itr = 8, residual norm = 1.1032E+01
# Itr = 9, residual norm = 4.4345E+01
# Itr = 10, residual norm = 1.6564E+01
# Itr = 11, residual norm = 4.3435E+01
# Itr = 12, residual norm = 1.5033E+01
# Itr = 13, residual norm = 6.8419E+01
# Itr = 14, residual norm = 2.0524E+01
# Itr = 15, residual norm = 1.0216E+04
# Itr = 16, residual norm = 2.5558E+03
# Itr = 17, residual norm = 6.4189E+02
# Itr = 18, residual norm = 1.7168E+02
# Itr = 19, residual norm = 8.6754E+01
# Itr = 20, residual norm = 1.1489E+02
# Itr = 21, residual norm = 6.5292E+01
# Itr = 22, residual norm = 5.8464E+02
# Itr = 23, residual norm = 1.0372E+03
# Itr = 24, residual norm = 2.4541E+02
# Itr = 25, residual norm = 3.4017E+01
# Itr = 26, residual norm = 3.5526E+02
# Itr = 27, residual norm = 7.8533E+01
# Itr = 28, residual norm = 1.5220E+01
# Itr = 29, residual norm = 7.2156E+01
# Itr = 30, residual norm = 1.2870E+01
# Itr = 31, residual norm = 5.8484E+01
# Itr = 32, residual norm = 1.4869E+01
# Itr = 33, residual norm = 1.0297E+00
# Itr = 34, residual norm = 2.8469E-02
# Itr = 35, residual norm = 6.0395E-06
# Itr = 36, residual norm = 9.7184E-13
# Time = 0.02100000000000002, dt = 0.0003333333333333333
# Itr = 0, residual norm = 4.7929E+01
# Itr = 1, residual norm = 4.5726E+01
# Itr = 2, residual norm = 1.5521E+02
# Itr = 3, residual norm = 2.1140E+03
# Itr = 4, residual norm = 3.2277E+03
# Itr = 5, residual norm = 8.7461E+02
# Itr = 6, residual norm = 2.6133E+02
# Itr = 7, residual norm = 4.7310E+02
# Itr = 8, residual norm = 1.4937E+03
# Itr = 9, residual norm = 5.4451E+02
# Itr = 10, residual norm = 6.1408E+02
# Itr = 11, residual norm = 3.8133E+03
# Itr = 12, residual norm = 8.5824E+02
# Itr = 13, residual norm = 6.3802E+02
# Itr = 14, residual norm = 3.1526E+02
# Itr = 15, residual norm = 8.0697E+06
# Itr = 16, residual norm = 2.0174E+06
# Itr = 17, residual norm = 5.0434E+05
# Itr = 18, residual norm = 1.2607E+05
# Itr = 19, residual norm = 3.1512E+04
# Itr = 20, residual norm = 7.8752E+03
# Itr = 21, residual norm = 1.9548E+03
# Itr = 22, residual norm = 5.1991E+02
# Itr = 23, residual norm = 4.2887E+02
# Itr = 24, residual norm = 9.1067E+03
# Itr = 25, residual norm = 2.2943E+03
# Itr = 26, residual norm = 5.6765E+02
# Itr = 27, residual norm = 1.9538E+02
# Itr = 28, residual norm = 2.1151E+02
# Itr = 29, residual norm = 6.0050E+01
# Itr = 30, residual norm = 3.4106E+01
# Itr = 31, residual norm = 5.9544E+03
# Itr = 32, residual norm = 1.4937E+03
# Itr = 33, residual norm = 4.0238E+02
# Itr = 34, residual norm = 1.6711E+02
# Itr = 35, residual norm = 8.6154E+01
# Itr = 36, residual norm = 1.3325E+02
# Itr = 37, residual norm = 3.3062E+03
# Itr = 38, residual norm = 8.1359E+02
# Itr = 39, residual norm = 1.3096E+03
# Itr = 40, residual norm = 2.6609E+02
# Itr = 41, residual norm = 1.1999E+02
# Itr = 42, residual norm = 1.4776E+03
# Itr = 43, residual norm = 3.8924E+02
# Itr = 44, residual norm = 8.7139E+01
# Itr = 45, residual norm = 3.0679E+01
# Itr = 46, residual norm = 4.9157E+02
# Itr = 47, residual norm = 1.2270E+02
# Itr = 48, residual norm = 3.8653E+01
# Itr = 49, residual norm = 1.6163E+01
# Itr = 50, residual norm = 6.5746E+00
# Time = 0.02083333333333335, dt = 0.00016666666666666666
# Itr = 0, residual norm = 2.3965E+01
# Itr = 1, residual norm = 1.2295E+02
# Itr = 2, residual norm = 2.6747E+02
# Itr = 3, residual norm = 1.7563E+03
# Itr = 4, residual norm = 5.1022E+02
# Itr = 5, residual norm = 1.0582E+03
# Itr = 6, residual norm = 4.2369E+02
# Itr = 7, residual norm = 2.1926E+03
# Itr = 8, residual norm = 9.1985E+02
# Itr = 9, residual norm = 2.9668E+02
# Itr = 10, residual norm = 1.1250E+02
# Itr = 11, residual norm = 2.5492E+03
# Itr = 12, residual norm = 8.3841E+04
# Itr = 13, residual norm = 2.0182E+04
# Itr = 14, residual norm = 2.0295E+04
# Itr = 15, residual norm = 4.8651E+03
# Itr = 16, residual norm = 3.7572E+03
# Itr = 17, residual norm = 6.1376E+03
# Itr = 18, residual norm = 1.2397E+03
# Itr = 19, residual norm = 2.9356E+02
# Itr = 20, residual norm = 1.0630E+02
# Itr = 21, residual norm = 3.3895E+02
# Itr = 22, residual norm = 8.9036E+02
# Itr = 23, residual norm = 6.2757E+02
# Itr = 24, residual norm = 1.0961E+04
# Itr = 25, residual norm = 2.7367E+03
# Itr = 26, residual norm = 7.0029E+02
# Itr = 27, residual norm = 1.8283E+02
# Itr = 28, residual norm = 4.6993E+02
# Itr = 29, residual norm = 1.7227E+02
# Itr = 30, residual norm = 1.3388E+05
# Itr = 31, residual norm = 3.3473E+04
# Itr = 32, residual norm = 8.3665E+03
# Itr = 33, residual norm = 1.9654E+03
# Itr = 34, residual norm = 2.8875E+05
# Itr = 35, residual norm = 7.1919E+04
# Itr = 36, residual norm = 3.2438E+04
# Itr = 37, residual norm = 5.6682E+03
# Itr = 38, residual norm = 2.8993E+03
# Itr = 39, residual norm = 1.5739E+04
# Itr = 40, residual norm = 2.6876E+03
# Itr = 41, residual norm = 2.7608E+03
# Itr = 42, residual norm = 1.7903E+04
# Itr = 43, residual norm = 1.5688E+04
# Itr = 44, residual norm = 6.2529E+03
# Itr = 45, residual norm = 2.1516E+03
# Itr = 46, residual norm = 4.3597E+02
# Itr = 47, residual norm = 1.6667E+02
# Itr = 48, residual norm = 2.1202E+03
# Itr = 49, residual norm = 1.0376E+03
# Itr = 50, residual norm = 1.4150E+03
# Time = 0.02075000000000002, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 1.1982E+01
# Itr = 1, residual norm = 1.7662E+01
# Itr = 2, residual norm = 1.4852E+03
# Itr = 3, residual norm = 3.7365E+02
# Itr = 4, residual norm = 1.0260E+02
# Itr = 5, residual norm = 2.3230E+01
# Itr = 6, residual norm = 4.9168E+00
# Itr = 7, residual norm = 1.0278E-01
# Itr = 8, residual norm = 6.6010E-04
# Itr = 9, residual norm = 3.3704E-09
# Time = 0.020833333333333353, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 3.4102E+01
# Itr = 1, residual norm = 4.2539E+01
# Itr = 2, residual norm = 1.5964E+01
# Itr = 3, residual norm = 1.0644E+00
# Itr = 4, residual norm = 2.4027E-02
# Itr = 5, residual norm = 4.6889E-06
# Itr = 6, residual norm = 2.2236E-13
# Time = 0.020916666666666688, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 4.3255E+01
# Itr = 1, residual norm = 3.7563E+01
# Itr = 2, residual norm = 1.3991E+01
# Itr = 3, residual norm = 1.6483E+01
# Itr = 4, residual norm = 1.7347E+00
# Itr = 5, residual norm = 2.3316E-02
# Itr = 6, residual norm = 2.4278E-05
# Itr = 7, residual norm = 1.0305E-11
# Time = 0.021000000000000022, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 3.4479E+01
# Itr = 1, residual norm = 3.2106E+01
# Itr = 2, residual norm = 2.5189E+02
# Itr = 3, residual norm = 5.6651E+01
# Itr = 4, residual norm = 7.7841E+00
# Itr = 5, residual norm = 6.2830E-01
# Itr = 6, residual norm = 1.7893E-02
# Itr = 7, residual norm = 3.9221E-06
# Itr = 8, residual norm = 9.3549E-14
# Time = 0.021083333333333357, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 4.6156E+01
# Itr = 1, residual norm = 6.4469E+01
# Itr = 2, residual norm = 7.4909E+01
# Itr = 3, residual norm = 5.2410E+01
# Itr = 4, residual norm = 6.4274E+02
# Itr = 5, residual norm = 1.6736E+02
# Itr = 6, residual norm = 2.3561E+02
# Itr = 7, residual norm = 2.4214E+02
# Itr = 8, residual norm = 1.5187E+02
# Itr = 9, residual norm = 1.4183E+03
# Itr = 10, residual norm = 3.4559E+02
# Itr = 11, residual norm = 1.0713E+02
# Itr = 12, residual norm = 1.1609E+04
# Itr = 13, residual norm = 2.8972E+03
# Itr = 14, residual norm = 7.2923E+02
# Itr = 15, residual norm = 9.7736E+03
# Itr = 16, residual norm = 2.2843E+03
# Itr = 17, residual norm = 6.5505E+02
# Itr = 18, residual norm = 5.3014E+04
# Itr = 19, residual norm = 1.3286E+04
# Itr = 20, residual norm = 7.5530E+04
# Itr = 21, residual norm = 1.8387E+04
# Itr = 22, residual norm = 5.6131E+03
# Itr = 23, residual norm = 1.2967E+03
# Itr = 24, residual norm = 6.1053E+02
# Itr = 25, residual norm = 1.5743E+02
# Itr = 26, residual norm = 2.2724E+02
# Itr = 27, residual norm = 5.7359E+04
# Itr = 28, residual norm = 1.4266E+04
# Itr = 29, residual norm = 3.0866E+03
# Itr = 30, residual norm = 5.7730E+02
# Itr = 31, residual norm = 3.8470E+02
# Itr = 32, residual norm = 2.3713E+03
# Itr = 33, residual norm = 1.0711E+03
# Itr = 34, residual norm = 3.5780E+02
# Itr = 35, residual norm = 2.2730E+02
# Itr = 36, residual norm = 7.5033E+02
# Itr = 37, residual norm = 1.6929E+02
# Itr = 38, residual norm = 1.1574E+02
# Itr = 39, residual norm = 5.4182E+01
# Itr = 40, residual norm = 3.1204E+01
# Itr = 41, residual norm = 7.8100E+02
# Itr = 42, residual norm = 2.2598E+02
# Itr = 43, residual norm = 8.8864E+01
# Itr = 44, residual norm = 1.6303E+01
# Itr = 45, residual norm = 6.0754E+02
# Itr = 46, residual norm = 1.5725E+02
# Itr = 47, residual norm = 5.5725E+01
# Itr = 48, residual norm = 9.4936E+03
# Itr = 49, residual norm = 2.3675E+03
# Itr = 50, residual norm = 5.8575E+02
# Time = 0.021041666666666688, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 2.3078E+01
# Itr = 1, residual norm = 7.7809E+03
# Itr = 2, residual norm = 1.9435E+03
# Itr = 3, residual norm = 5.2340E+02
# Itr = 4, residual norm = 1.1369E+03
# Itr = 5, residual norm = 3.1188E+02
# Itr = 6, residual norm = 1.2442E+04
# Itr = 7, residual norm = 3.0642E+03
# Itr = 8, residual norm = 1.0043E+04
# Itr = 9, residual norm = 2.7204E+03
# Itr = 10, residual norm = 7.9054E+02
# Itr = 11, residual norm = 1.3649E+03
# Itr = 12, residual norm = 3.2564E+02
# Itr = 13, residual norm = 8.4406E+02
# Itr = 14, residual norm = 2.9107E+02
# Itr = 15, residual norm = 1.1217E+02
# Itr = 16, residual norm = 6.4681E+02
# Itr = 17, residual norm = 2.9043E+02
# Itr = 18, residual norm = 1.4936E+02
# Itr = 19, residual norm = 4.3659E+01
# Itr = 20, residual norm = 4.8955E+00
# Itr = 21, residual norm = 1.5054E-01
# Itr = 22, residual norm = 1.6058E-04
# Itr = 23, residual norm = 3.3581E-11
# Time = 0.021083333333333353, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 3.0873E+02
# Itr = 1, residual norm = 3.6144E+02
# Itr = 2, residual norm = 1.0648E+03
# Itr = 3, residual norm = 1.8745E+03
# Itr = 4, residual norm = 4.4401E+02
# Itr = 5, residual norm = 8.0536E+03
# Itr = 6, residual norm = 1.8833E+03
# Itr = 7, residual norm = 2.3637E+04
# Itr = 8, residual norm = 5.7372E+03
# Itr = 9, residual norm = 2.8113E+03
# Itr = 10, residual norm = 2.2692E+03
# Itr = 11, residual norm = 1.6770E+03
# Itr = 12, residual norm = 2.1126E+03
# Itr = 13, residual norm = 2.0242E+03
# Itr = 14, residual norm = 8.0591E+02
# Itr = 15, residual norm = 1.2351E+04
# Itr = 16, residual norm = 2.9782E+03
# Itr = 17, residual norm = 9.7436E+02
# Itr = 18, residual norm = 7.1318E+04
# Itr = 19, residual norm = 1.7867E+04
# Itr = 20, residual norm = 4.5943E+03
# Itr = 21, residual norm = 3.2964E+03
# Itr = 22, residual norm = 1.6913E+04
# Itr = 23, residual norm = 3.7562E+03
# Itr = 24, residual norm = 2.3250E+03
# Itr = 25, residual norm = 1.1739E+04
# Itr = 26, residual norm = 2.6842E+03
# Itr = 27, residual norm = 7.3578E+02
# Itr = 28, residual norm = 1.6571E+03
# Itr = 29, residual norm = 1.2770E+03
# Itr = 30, residual norm = 1.4648E+03
# Itr = 31, residual norm = 3.4014E+04
# Itr = 32, residual norm = 6.3728E+03
# Itr = 33, residual norm = 1.4470E+04
# Itr = 34, residual norm = 5.8071E+03
# Itr = 35, residual norm = 1.5215E+03
# Itr = 36, residual norm = 4.9822E+03
# Itr = 37, residual norm = 1.0094E+04
# Itr = 38, residual norm = 3.1906E+03
# Itr = 39, residual norm = 9.9867E+03
# Itr = 40, residual norm = 2.1931E+03
# Itr = 41, residual norm = 2.6493E+03
# Itr = 42, residual norm = 9.6580E+02
# Itr = 43, residual norm = 1.6954E+06
# Itr = 44, residual norm = 4.2373E+05
# Itr = 45, residual norm = 1.0580E+05
# Itr = 46, residual norm = 2.6106E+04
# Itr = 47, residual norm = 3.8009E+04
# Itr = 48, residual norm = 3.3597E+06
# Itr = 49, residual norm = 7.5848E+05
# Itr = 50, residual norm = 2.0111E+05
# Time = 0.021062500000000022, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 1.5436E+02
# Itr = 1, residual norm = 6.8660E+03
# Itr = 2, residual norm = 1.7518E+03
# Itr = 3, residual norm = 4.3461E+02
# Itr = 4, residual norm = 1.7218E+02
# Itr = 5, residual norm = 4.9523E+02
# Itr = 6, residual norm = 1.9354E+02
# Itr = 7, residual norm = 3.5750E+02
# Itr = 8, residual norm = 1.8942E+02
# Itr = 9, residual norm = 1.0448E+07
# Itr = 10, residual norm = 2.6120E+06
# Itr = 11, residual norm = 6.5303E+05
# Itr = 12, residual norm = 1.6329E+05
# Itr = 13, residual norm = 4.0870E+04
# Itr = 14, residual norm = 1.0253E+04
# Itr = 15, residual norm = 2.8022E+03
# Itr = 16, residual norm = 8.0684E+03
# Itr = 17, residual norm = 2.1150E+03
# Itr = 18, residual norm = 5.5894E+03
# Itr = 19, residual norm = 1.4769E+03
# Itr = 20, residual norm = 7.7687E+03
# Itr = 21, residual norm = 1.7634E+03
# Itr = 22, residual norm = 1.2386E+04
# Itr = 23, residual norm = 4.0805E+03
# Itr = 24, residual norm = 2.9026E+06
# Itr = 25, residual norm = 7.2568E+05
# Itr = 26, residual norm = 1.8137E+05
# Itr = 27, residual norm = 5.3443E+04
# Itr = 28, residual norm = 1.5972E+04
# Itr = 29, residual norm = 1.1767E+04
# Itr = 30, residual norm = 1.8807E+04
# Itr = 31, residual norm = 4.4731E+03
# Itr = 32, residual norm = 2.9671E+03
# Itr = 33, residual norm = 2.9966E+05
# Itr = 34, residual norm = 7.5019E+04
# Itr = 35, residual norm = 1.8716E+04
# Itr = 36, residual norm = 1.6398E+04
# Itr = 37, residual norm = 2.2830E+05
# Itr = 38, residual norm = 5.6784E+04
# Itr = 39, residual norm = 2.3470E+04
# Itr = 40, residual norm = 5.5336E+03
# Itr = 41, residual norm = 7.0069E+04
# Itr = 42, residual norm = 2.4574E+04
# Itr = 43, residual norm = 1.4221E+05
# Itr = 44, residual norm = 5.0554E+04
# Itr = 45, residual norm = 1.5695E+04
# Itr = 46, residual norm = 4.2458E+04
# Itr = 47, residual norm = 2.7312E+05
# Itr = 48, residual norm = 1.1845E+06
# Itr = 49, residual norm = 2.7050E+06
# Itr = 50, residual norm = 6.7346E+05
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[32], line 9
#       8 try:
# ----> 9     x_red = nr_solve(f, df, x_red, args=(x_red, dt))
#      10 except:
#
# Cell In[29], line 13, in nr_solve(f, df, x, atol, rtol, max_itr, args)
#      12         return x
# ---> 13 raise Exception("solve failed")
#
# Exception: solve failed
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[32], line 13
#      11     dt = dt / 2
#      12     if (dt < dt_min):
# ---> 13         raise Exception("dt is too small")
#      14     continue
#      15 t = t + dt
#
# Exception: dt is too small

# %%
t/(2/1500)
# Out:
# 15.781250000000016

# %%
ref_sol = X_test[15].detach().cpu().numpy()
approximate = (nrbs.decode(torch.tensor(sol[t]).to(device)) + x_ref).detach().cpu().numpy()
np.sqrt(np.sum(approximate - ref_sol)**2) / np.sqrt(np.sum(ref_sol**2))
# Out:
# 226.77338523132983

# %%
# approximate = (nrbs.decode(sol[t]) + x_ref).detach().cpu().numpy()
# # plot
# ny = 60
# nx = 60
# x = np.load('paper_x.npy')
# y = np.load('paper_y.npy')


# fig_u = plt.figure()
# ax_u = fig_u.gca()
# p_u=ax_u.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), (approximate).reshape(ny,nx))
# cb_u=fig_u.colorbar(p_u,ax=ax_u)
# ax_u.set_xlabel('$x$')
# ax_u.set_ylabel('$y$')
# plt.title('$u$ ($t = {:}$)'.format(t))
# plt.show()

# %%
# for t, x_red in sol.items():
#     approximate = (nrbs.decode(x_red) + x_ref).detach().cpu().numpy()
#     # plot
#     ny = 60
#     nx = 60
#     x = np.load('paper_x.npy')
#     y = np.load('paper_y.npy')


#     fig_u = plt.figure()
#     ax_u = fig_u.gca()
#     p_u=ax_u.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), (approximate).reshape(ny,nx))
#     cb_u=fig_u.colorbar(p_u,ax=ax_u)
#     ax_u.set_xlabel('$x$')
#     ax_u.set_ylabel('$y$')
#     plt.title('$u$ ($t = {:}$)'.format(t))
#     plt.show()
