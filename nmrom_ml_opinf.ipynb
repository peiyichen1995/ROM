# %%
import torch
import numpy as np

torch.set_default_dtype(torch.float64)

from torch.utils.tensorboard import SummaryWriter
import tqdm

from matplotlib import pyplot as plt

# %%
device = torch.device("cuda")

# %%
data1 = torch.tensor(np.load("mu_0.9.npy")).to(device)
data2 = torch.tensor(np.load("mu_0.95.npy")).to(device)
data3 = torch.tensor(np.load("mu_1.05.npy")).to(device)
data4 = torch.tensor(np.load("mu_1.1.npy")).to(device)

dt = 2 / 1500

X = torch.cat([data1, data2, data3, data4], axis=0)
x_ref = torch.mean(X, dim=0)
(S, N) = X.shape

X_test = torch.tensor(np.load("mu_1.0.npy")).to(device)

# %%
class NRBS(torch.nn.Module):
    def __init__(self, N, n, M1, M2, b):
        super(NRBS, self).__init__()

        mask = torch.zeros(N, M2)
        shift = (M2 - b) / (N - 1)

        for i in range(N):
            mask[i, int(np.ceil(shift*i)): int(np.ceil(shift*i)) + b] = 1

        new_mask = torch.zeros(N, M2)

        for idx in range(N):
            i = idx // 60
            j = idx % 60
            neighbours = [(i, j), (i-1, j), (i+1, j), (i, j+1), (i, j-1)]
            for neighbour_i, neighbour_j in neighbours:
              if (neighbour_i >=0 and neighbour_i < 60) and (neighbour_j >=0 and neighbour_j < 60):
                new_mask[idx] = new_mask[idx] + mask[60*neighbour_i + neighbour_j]

        new_mask[new_mask > 0] = 1

        self.register_buffer('mask', new_mask)


        self.encoder1 = torch.nn.Linear(N, M1)
        self.encoder2 = torch.nn.Linear(M1, n)

        self.decoder1 = torch.nn.Linear(n, M2)
        self.decoder2 = torch.nn.Linear(M2, N)

        torch.nn.init.kaiming_normal_(self.encoder1.weight)
        torch.nn.init.kaiming_normal_(self.encoder2.weight)
        torch.nn.init.kaiming_normal_(self.decoder1.weight)
        torch.nn.init.kaiming_normal_(self.decoder2.weight)

    def encode(self, x):
        x = self.encoder1(x)
        x = x * torch.sigmoid(x)
        x = self.encoder2(x)
        return x

    def decode(self, x):
        x = self.decoder1(x)
        x = x * torch.sigmoid(x)
        x = torch.matmul(x, (self.decoder2.weight * self.get_buffer('mask')).T) + self.decoder2.bias
        return x

    def forward(self, x):
        return self.decode(self.encode(x))

# %%
n = 20

nrbs = NRBS(N, n, 6728, 33730, 70).to(device)
nrbs = torch.load('models/shallow_mask_old.pth')

X_tilde = nrbs(X_test - x_ref) + x_ref
l_test = torch.sqrt(torch.sum((X_test - X_tilde) ** 2)) / torch.sqrt(
    torch.sum(X_test**2)
)
l_test
# Out:
# tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)

# %%
def u_hat_and_u_hat_dot(nrbs, u, u_ref, dt):
    with torch.no_grad():
        u_hat = nrbs.encode(u - u_ref)
        u_hat_dot = (u_hat[1:] - u_hat[:-1]) / dt
        u_hat = u_hat[1:]
    return u_hat, u_hat_dot

# %%
data1_hat, data1_hat_dot = u_hat_and_u_hat_dot(nrbs, data1, x_ref, dt)
data2_hat, data2_hat_dot = u_hat_and_u_hat_dot(nrbs, data2, x_ref, dt)
data3_hat, data3_hat_dot = u_hat_and_u_hat_dot(nrbs, data3, x_ref, dt)
data4_hat, data4_hat_dot = u_hat_and_u_hat_dot(nrbs, data4, x_ref, dt)

# %%
X_hat = torch.cat([data1_hat, data2_hat, data3_hat, data4_hat])
X_hat_dot = torch.cat([data1_hat_dot, data2_hat_dot, data3_hat_dot, data4_hat_dot])

X_hat_test, X_hat_dot_test = u_hat_and_u_hat_dot(nrbs, X_test, x_ref, dt)

# %%
class OP(torch.nn.Module):
    def __init__(self, n, M):
        super(OP, self).__init__()

        ls = []
        in_dim = n
        for dim in M:
            ls.append(torch.nn.Linear(in_dim, dim))
            in_dim = dim
        self.ls = torch.nn.ModuleList(ls)

        # self.residual = torch.nn.Linear(n, n)

    def forward(self, x):
        # residual = self.residual(x)
        for i in range(len(self.ls) - 1):
            x = self.ls[i](x)
            x = x * torch.sigmoid(x)
        x = self.ls[-1](x)
        # x = x + residual
        return x

# %%
lr = 1e-3
epochs = 10000
B = 240
lr_red_factor = 0.1
patience = 10
l1_reg = 0

# op = OP(n, [500, 1000, 500, n]).to(device)
op = OP(n, [600, 1000, 1200, 1000, 600, n]).to(device)
op = torch.load('models/operator.pth')

# %%
# with torch.no_grad():
#     approximates = op(X_hat_test)
#     l_test = torch.sum((X_hat_dot_test - approximates) ** 2)

# torch.sqrt(l_test) / torch.sqrt(torch.sum(X_hat_dot_test**2))

# %%
# data = torch.utils.data.TensorDataset(X_hat, X_hat_dot)
# dataloader = torch.utils.data.DataLoader(data, batch_size=B, shuffle=True)

# optimizer = torch.optim.Adam(op.parameters(), lr=lr, weight_decay=l1_reg)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#     optimizer, "min", factor=lr_red_factor, patience=patience
# )

# best_loss = 1000
# writer = SummaryWriter()
# for epoch in range(epochs):
#     for x, x_dot in tqdm.tqdm(dataloader):
#         optimizer.zero_grad()
#         loss = torch.sqrt(torch.sum((op(x) - x_dot) ** 2))
#         loss.backward()
#         # print(op.l1.weight.grad)
#         optimizer.step()

#     with torch.no_grad():
#         approximates = op(X_hat)
#         l_train = torch.sum((X_hat_dot - approximates) ** 2)

#         approximates = op(X_hat_test)
#         l_test = torch.sum((X_hat_dot_test - approximates) ** 2)

#     if (l_train < best_loss):
#         best_loss = l_train
#         torch.save(op, 'models/operator.pth')
        

#     scheduler.step(l_train)

#     writer.add_scalar("loss/train", torch.sqrt(l_train) / torch.sqrt(torch.sum(X_hat_dot**2)), epoch)
#     writer.add_scalar("loss/mse_train", l_train / X_hat_dot.shape[1] / X_hat_dot.shape[0], epoch)
    
#     writer.add_scalar("loss/test", torch.sqrt(l_test) / torch.sqrt(torch.sum(X_hat_dot_test**2)), epoch)
#     writer.add_scalar("loss/mse_train", l_test / X_hat_dot_test.shape[1] / X_hat_dot_test.shape[0], epoch)

#     writer.add_scalar("lr", optimizer.param_groups[0]["lr"], epoch)
#     print(torch.sqrt(l_train) / torch.sqrt(torch.sum(X_hat_dot**2)))
#     print(torch.sqrt(l_test) / torch.sqrt(torch.sum(X_hat_dot_test**2)))

# %%
# test = X_hat_test[0]
# test.requires_grad = True
# test_dot = op(test)

# %%
# basis = torch.zeros(n, n)
# for i in range(n):
#     inplace = torch.zeros_like(test_dot)
#     inplace[i] = 1
#     basis[:, i] = torch.autograd.grad(test_dot, test, inplace, retain_graph=True)[0]

# %%
def nr_solve(f, df, x, atol=1e-10, rtol=1e-8, max_itr=50, args=None):
    r = f(x, *args)
    r0_norm = torch.linalg.norm(r)
    print("Itr = {:}, residual norm = {:.4E}".format(0, r0_norm))
    if (r0_norm < atol):
        return x
    for i in range(max_itr):
        x = torch.linalg.solve(df(x, *args), -r) + x
        r = f(x, *args)
        print("Itr = {:}, residual norm = {:.4E}".format(i + 1, torch.linalg.norm(r)))
        if (torch.linalg.norm(r) < atol or torch.linalg.norm(r) / r0_norm < rtol):
            return x
    raise Exception("solve failed")

# %%
# replace with NN: u_hat to u_hat_dot
def f(x, x_old, dt):
    x_dot = op(x)
    return x - x_old - dt * x_dot

def df(x, x_old, dt):
    print(x.requires_grad)
    x_dot = op(x)
    d_s_dot = torch.zeros(n, n).to(device)
    for i in range(n):
        inplace = torch.zeros_like(x_dot)
        inplace[i] = 1
        d_s_dot[:, i] = torch.autograd.grad(x_dot, x, inplace, retain_graph=True)[0]

    return torch.eye(n).to(device) - d_s_dot * dt

# %%
# x_red = X_hat_test[0]
# x_red.requires_grad = True
# x_red = nr_solve(f, df, x_red, args=(x_red, dt))

# %%
x_red = X_hat_test[0]
x_red.requires_grad = True
t = 0
sol = {t : x_red}
dt = 2 / 1500
dt_min = dt / 100
while t < 2:
    print('Time = {:}, dt = {:}'.format(t + dt, dt))
    try:
        x_red = nr_solve(f, df, x_red, args=(x_red, dt))
    except:
        dt = dt / 2
        if (dt < dt_min):
            raise Exception("dt is too small")
        continue
    t = t + dt
    sol[t] = x_red
# Out:
# Time = 0.0013333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6855E-02
# True
# Itr = 1, residual norm = 1.5853E-03
# True
# Itr = 2, residual norm = 5.4467E-05
# True
# Itr = 3, residual norm = 1.8741E-06
# True
# Itr = 4, residual norm = 6.4387E-08
# True
# Itr = 5, residual norm = 2.2174E-09
# True
# Itr = 6, residual norm = 7.6118E-11
# Time = 0.0026666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6715E-02
# True
# Itr = 1, residual norm = 1.5782E-03
# True
# Itr = 2, residual norm = 5.4172E-05
# True
# Itr = 3, residual norm = 1.8618E-06
# True
# Itr = 4, residual norm = 6.3903E-08
# True
# Itr = 5, residual norm = 2.1981E-09
# True
# Itr = 6, residual norm = 7.5387E-11
# Time = 0.004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6570E-02
# True
# Itr = 1, residual norm = 1.5713E-03
# True
# Itr = 2, residual norm = 5.3886E-05
# True
# Itr = 3, residual norm = 1.8500E-06
# True
# Itr = 4, residual norm = 6.3446E-08
# True
# Itr = 5, residual norm = 2.1801E-09
# True
# Itr = 6, residual norm = 7.4708E-11
# Time = 0.005333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6422E-02
# True
# Itr = 1, residual norm = 1.5644E-03
# True
# Itr = 2, residual norm = 5.3607E-05
# True
# Itr = 3, residual norm = 1.8387E-06
# True
# Itr = 4, residual norm = 6.3010E-08
# True
# Itr = 5, residual norm = 2.1630E-09
# True
# Itr = 6, residual norm = 7.4068E-11
# Time = 0.006666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6270E-02
# True
# Itr = 1, residual norm = 1.5575E-03
# True
# Itr = 2, residual norm = 5.3332E-05
# True
# Itr = 3, residual norm = 1.8276E-06
# True
# Itr = 4, residual norm = 6.2590E-08
# True
# Itr = 5, residual norm = 2.1467E-09
# True
# Itr = 6, residual norm = 7.3460E-11
# Time = 0.008, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.6115E-02
# True
# Itr = 1, residual norm = 1.5505E-03
# True
# Itr = 2, residual norm = 5.3061E-05
# True
# Itr = 3, residual norm = 1.8168E-06
# True
# Itr = 4, residual norm = 6.2183E-08
# True
# Itr = 5, residual norm = 2.1310E-09
# True
# Itr = 6, residual norm = 7.2880E-11
# Time = 0.009333333333333334, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.5956E-02
# True
# Itr = 1, residual norm = 1.5436E-03
# True
# Itr = 2, residual norm = 5.2792E-05
# True
# Itr = 3, residual norm = 1.8063E-06
# True
# Itr = 4, residual norm = 6.1789E-08
# True
# Itr = 5, residual norm = 2.1159E-09
# True
# Itr = 6, residual norm = 7.2326E-11
# Time = 0.010666666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.5795E-02
# True
# Itr = 1, residual norm = 1.5366E-03
# True
# Itr = 2, residual norm = 5.2527E-05
# True
# Itr = 3, residual norm = 1.7960E-06
# True
# Itr = 4, residual norm = 6.1409E-08
# True
# Itr = 5, residual norm = 2.1014E-09
# True
# Itr = 6, residual norm = 7.1800E-11
# Time = 0.012000000000000002, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.5630E-02
# True
# Itr = 1, residual norm = 1.5296E-03
# True
# Itr = 2, residual norm = 5.2264E-05
# True
# Itr = 3, residual norm = 1.7860E-06
# True
# Itr = 4, residual norm = 6.1042E-08
# True
# Itr = 5, residual norm = 2.0876E-09
# True
# Itr = 6, residual norm = 7.1300E-11
# Time = 0.013333333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.5463E-02
# True
# Itr = 1, residual norm = 1.5226E-03
# True
# Itr = 2, residual norm = 5.2005E-05
# True
# Itr = 3, residual norm = 1.7762E-06
# True
# Itr = 4, residual norm = 6.0689E-08
# True
# Itr = 5, residual norm = 2.0744E-09
# True
# Itr = 6, residual norm = 7.0830E-11
# Time = 0.01466666666666667, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.5293E-02
# True
# Itr = 1, residual norm = 1.5156E-03
# True
# Itr = 2, residual norm = 5.1750E-05
# True
# Itr = 3, residual norm = 1.7667E-06
# True
# Itr = 4, residual norm = 6.0350E-08
# True
# Itr = 5, residual norm = 2.0619E-09
# True
# Itr = 6, residual norm = 7.0387E-11
# Time = 0.016000000000000004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.5120E-02
# True
# Itr = 1, residual norm = 1.5085E-03
# True
# Itr = 2, residual norm = 5.1497E-05
# True
# Itr = 3, residual norm = 1.7574E-06
# True
# Itr = 4, residual norm = 6.0024E-08
# True
# Itr = 5, residual norm = 2.0500E-09
# True
# Itr = 6, residual norm = 6.9971E-11
# Time = 0.017333333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.4944E-02
# True
# Itr = 1, residual norm = 1.5014E-03
# True
# Itr = 2, residual norm = 5.1247E-05
# True
# Itr = 3, residual norm = 1.7483E-06
# True
# Itr = 4, residual norm = 5.9710E-08
# True
# Itr = 5, residual norm = 2.0387E-09
# True
# Itr = 6, residual norm = 6.9579E-11
# Time = 0.018666666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.4766E-02
# True
# Itr = 1, residual norm = 1.4943E-03
# True
# Itr = 2, residual norm = 5.0999E-05
# True
# Itr = 3, residual norm = 1.7394E-06
# True
# Itr = 4, residual norm = 5.9406E-08
# True
# Itr = 5, residual norm = 2.0278E-09
# True
# Itr = 6, residual norm = 6.9207E-11
# Time = 0.02, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.4585E-02
# True
# Itr = 1, residual norm = 1.4871E-03
# True
# Itr = 2, residual norm = 5.0752E-05
# True
# Itr = 3, residual norm = 1.7307E-06
# True
# Itr = 4, residual norm = 5.9110E-08
# True
# Itr = 5, residual norm = 2.0173E-09
# True
# Itr = 6, residual norm = 6.8852E-11
# Time = 0.021333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.4402E-02
# True
# Itr = 1, residual norm = 1.4799E-03
# True
# Itr = 2, residual norm = 5.0505E-05
# True
# Itr = 3, residual norm = 1.7220E-06
# True
# Itr = 4, residual norm = 5.8819E-08
# True
# Itr = 5, residual norm = 2.0071E-09
# True
# Itr = 6, residual norm = 6.8510E-11
# Time = 0.022666666666666665, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.4216E-02
# True
# Itr = 1, residual norm = 1.4726E-03
# True
# Itr = 2, residual norm = 5.0258E-05
# True
# Itr = 3, residual norm = 1.7134E-06
# True
# Itr = 4, residual norm = 5.8533E-08
# True
# Itr = 5, residual norm = 1.9971E-09
# True
# Itr = 6, residual norm = 6.8178E-11
# Time = 0.023999999999999997, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.4027E-02
# True
# Itr = 1, residual norm = 1.4653E-03
# True
# Itr = 2, residual norm = 5.0011E-05
# True
# Itr = 3, residual norm = 1.7048E-06
# True
# Itr = 4, residual norm = 5.8249E-08
# True
# Itr = 5, residual norm = 1.9872E-09
# True
# Itr = 6, residual norm = 6.7855E-11
# Time = 0.02533333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.3836E-02
# True
# Itr = 1, residual norm = 1.4578E-03
# True
# Itr = 2, residual norm = 4.9762E-05
# True
# Itr = 3, residual norm = 1.6963E-06
# True
# Itr = 4, residual norm = 5.7970E-08
# True
# Itr = 5, residual norm = 1.9776E-09
# True
# Itr = 6, residual norm = 6.7542E-11
# Time = 0.02666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.3643E-02
# True
# Itr = 1, residual norm = 1.4504E-03
# True
# Itr = 2, residual norm = 4.9514E-05
# True
# Itr = 3, residual norm = 1.6879E-06
# True
# Itr = 4, residual norm = 5.7697E-08
# True
# Itr = 5, residual norm = 1.9683E-09
# True
# Itr = 6, residual norm = 6.7243E-11
# Time = 0.027999999999999994, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.3447E-02
# True
# Itr = 1, residual norm = 1.4428E-03
# True
# Itr = 2, residual norm = 4.9268E-05
# True
# Itr = 3, residual norm = 1.6796E-06
# True
# Itr = 4, residual norm = 5.7433E-08
# True
# Itr = 5, residual norm = 1.9594E-09
# True
# Itr = 6, residual norm = 6.6963E-11
# Time = 0.029333333333333326, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.3248E-02
# True
# Itr = 1, residual norm = 1.4353E-03
# True
# Itr = 2, residual norm = 4.9025E-05
# True
# Itr = 3, residual norm = 1.6715E-06
# True
# Itr = 4, residual norm = 5.7183E-08
# True
# Itr = 5, residual norm = 1.9512E-09
# True
# Itr = 6, residual norm = 6.6710E-11
# Time = 0.030666666666666658, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.3047E-02
# True
# Itr = 1, residual norm = 1.4277E-03
# True
# Itr = 2, residual norm = 4.8787E-05
# True
# Itr = 3, residual norm = 1.6639E-06
# True
# Itr = 4, residual norm = 5.6951E-08
# True
# Itr = 5, residual norm = 1.9438E-09
# True
# Itr = 6, residual norm = 6.6494E-11
# Time = 0.031999999999999994, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.2844E-02
# True
# Itr = 1, residual norm = 1.4202E-03
# True
# Itr = 2, residual norm = 4.8555E-05
# True
# Itr = 3, residual norm = 1.6566E-06
# True
# Itr = 4, residual norm = 5.6742E-08
# True
# Itr = 5, residual norm = 1.9374E-09
# True
# Itr = 6, residual norm = 6.6323E-11
# Time = 0.033333333333333326, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.2638E-02
# True
# Itr = 1, residual norm = 1.4127E-03
# True
# Itr = 2, residual norm = 4.8333E-05
# True
# Itr = 3, residual norm = 1.6499E-06
# True
# Itr = 4, residual norm = 5.6562E-08
# True
# Itr = 5, residual norm = 1.9323E-09
# True
# Itr = 6, residual norm = 6.6206E-11
# Time = 0.03466666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.2431E-02
# True
# Itr = 1, residual norm = 1.4053E-03
# True
# Itr = 2, residual norm = 4.8120E-05
# True
# Itr = 3, residual norm = 1.6439E-06
# True
# Itr = 4, residual norm = 5.6413E-08
# True
# Itr = 5, residual norm = 1.9286E-09
# True
# Itr = 6, residual norm = 6.6149E-11
# Time = 0.03599999999999999, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.2220E-02
# True
# Itr = 1, residual norm = 1.3979E-03
# True
# Itr = 2, residual norm = 4.7919E-05
# True
# Itr = 3, residual norm = 1.6385E-06
# True
# Itr = 4, residual norm = 5.6298E-08
# True
# Itr = 5, residual norm = 1.9265E-09
# True
# Itr = 6, residual norm = 6.6159E-11
# Time = 0.03733333333333332, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.2008E-02
# True
# Itr = 1, residual norm = 1.3906E-03
# True
# Itr = 2, residual norm = 4.7729E-05
# True
# Itr = 3, residual norm = 1.6338E-06
# True
# Itr = 4, residual norm = 5.6220E-08
# True
# Itr = 5, residual norm = 1.9259E-09
# True
# Itr = 6, residual norm = 6.6238E-11
# Time = 0.038666666666666655, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.1794E-02
# True
# Itr = 1, residual norm = 1.3834E-03
# True
# Itr = 2, residual norm = 4.7551E-05
# True
# Itr = 3, residual norm = 1.6299E-06
# True
# Itr = 4, residual norm = 5.6178E-08
# True
# Itr = 5, residual norm = 1.9271E-09
# True
# Itr = 6, residual norm = 6.6389E-11
# Time = 0.03999999999999999, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.1577E-02
# True
# Itr = 1, residual norm = 1.3763E-03
# True
# Itr = 2, residual norm = 4.7385E-05
# True
# Itr = 3, residual norm = 1.6267E-06
# True
# Itr = 4, residual norm = 5.6174E-08
# True
# Itr = 5, residual norm = 1.9299E-09
# True
# Itr = 6, residual norm = 6.6614E-11
# Time = 0.04133333333333332, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.1359E-02
# True
# Itr = 1, residual norm = 1.3693E-03
# True
# Itr = 2, residual norm = 4.7231E-05
# True
# Itr = 3, residual norm = 1.6242E-06
# True
# Itr = 4, residual norm = 5.6207E-08
# True
# Itr = 5, residual norm = 1.9344E-09
# True
# Itr = 6, residual norm = 6.6912E-11
# Time = 0.04266666666666665, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.1138E-02
# True
# Itr = 1, residual norm = 1.3623E-03
# True
# Itr = 2, residual norm = 4.7088E-05
# True
# Itr = 3, residual norm = 1.6225E-06
# True
# Itr = 4, residual norm = 5.6278E-08
# True
# Itr = 5, residual norm = 1.9406E-09
# True
# Itr = 6, residual norm = 6.7285E-11
# Time = 0.043999999999999984, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.0916E-02
# True
# Itr = 1, residual norm = 1.3554E-03
# True
# Itr = 2, residual norm = 4.6956E-05
# True
# Itr = 3, residual norm = 1.6215E-06
# True
# Itr = 4, residual norm = 5.6386E-08
# True
# Itr = 5, residual norm = 1.9486E-09
# True
# Itr = 6, residual norm = 6.7735E-11
# Time = 0.045333333333333316, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.0692E-02
# True
# Itr = 1, residual norm = 1.3486E-03
# True
# Itr = 2, residual norm = 4.6836E-05
# True
# Itr = 3, residual norm = 1.6212E-06
# True
# Itr = 4, residual norm = 5.6533E-08
# True
# Itr = 5, residual norm = 1.9583E-09
# True
# Itr = 6, residual norm = 6.8265E-11
# Time = 0.04666666666666665, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.0467E-02
# True
# Itr = 1, residual norm = 1.3419E-03
# True
# Itr = 2, residual norm = 4.6729E-05
# True
# Itr = 3, residual norm = 1.6217E-06
# True
# Itr = 4, residual norm = 5.6721E-08
# True
# Itr = 5, residual norm = 1.9700E-09
# True
# Itr = 6, residual norm = 6.8881E-11
# Time = 0.04799999999999998, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.0241E-02
# True
# Itr = 1, residual norm = 1.3353E-03
# True
# Itr = 2, residual norm = 4.6634E-05
# True
# Itr = 3, residual norm = 1.6230E-06
# True
# Itr = 4, residual norm = 5.6954E-08
# True
# Itr = 5, residual norm = 1.9837E-09
# True
# Itr = 6, residual norm = 6.9589E-11
# Time = 0.04933333333333331, dt = 0.0013333333333333333
# Itr = 0, residual norm = 4.0013E-02
# True
# Itr = 1, residual norm = 1.3288E-03
# True
# Itr = 2, residual norm = 4.6554E-05
# True
# Itr = 3, residual norm = 1.6253E-06
# True
# Itr = 4, residual norm = 5.7234E-08
# True
# Itr = 5, residual norm = 1.9997E-09
# True
# Itr = 6, residual norm = 7.0400E-11
# Time = 0.050666666666666645, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.9784E-02
# True
# Itr = 1, residual norm = 1.3225E-03
# True
# Itr = 2, residual norm = 4.6491E-05
# True
# Itr = 3, residual norm = 1.6285E-06
# True
# Itr = 4, residual norm = 5.7569E-08
# True
# Itr = 5, residual norm = 2.0182E-09
# True
# Itr = 6, residual norm = 7.1327E-11
# Time = 0.05199999999999998, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.9555E-02
# True
# Itr = 1, residual norm = 1.3163E-03
# True
# Itr = 2, residual norm = 4.6445E-05
# True
# Itr = 3, residual norm = 1.6330E-06
# True
# Itr = 4, residual norm = 5.7965E-08
# True
# Itr = 5, residual norm = 2.0397E-09
# True
# Itr = 6, residual norm = 7.2385E-11
# Time = 0.05333333333333331, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.9325E-02
# True
# Itr = 1, residual norm = 1.3103E-03
# True
# Itr = 2, residual norm = 4.6421E-05
# True
# Itr = 3, residual norm = 1.6387E-06
# True
# Itr = 4, residual norm = 5.8429E-08
# True
# Itr = 5, residual norm = 2.0643E-09
# True
# Itr = 6, residual norm = 7.3591E-11
# Time = 0.05466666666666664, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.9094E-02
# True
# Itr = 1, residual norm = 1.3046E-03
# True
# Itr = 2, residual norm = 4.6419E-05
# True
# Itr = 3, residual norm = 1.6458E-06
# True
# Itr = 4, residual norm = 5.8970E-08
# True
# Itr = 5, residual norm = 2.0926E-09
# True
# Itr = 6, residual norm = 7.4964E-11
# Time = 0.05599999999999997, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.8863E-02
# True
# Itr = 1, residual norm = 1.2991E-03
# True
# Itr = 2, residual norm = 4.6443E-05
# True
# Itr = 3, residual norm = 1.6546E-06
# True
# Itr = 4, residual norm = 5.9594E-08
# True
# Itr = 5, residual norm = 2.1249E-09
# True
# Itr = 6, residual norm = 7.6525E-11
# Time = 0.057333333333333306, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.8632E-02
# True
# Itr = 1, residual norm = 1.2938E-03
# True
# Itr = 2, residual norm = 4.6494E-05
# True
# Itr = 3, residual norm = 1.6650E-06
# True
# Itr = 4, residual norm = 6.0310E-08
# True
# Itr = 5, residual norm = 2.1617E-09
# True
# Itr = 6, residual norm = 7.8293E-11
# Time = 0.05866666666666664, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.8402E-02
# True
# Itr = 1, residual norm = 1.2889E-03
# True
# Itr = 2, residual norm = 4.6573E-05
# True
# Itr = 3, residual norm = 1.6772E-06
# True
# Itr = 4, residual norm = 6.1124E-08
# True
# Itr = 5, residual norm = 2.2033E-09
# True
# Itr = 6, residual norm = 8.0289E-11
# Time = 0.05999999999999997, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.8171E-02
# True
# Itr = 1, residual norm = 1.2842E-03
# True
# Itr = 2, residual norm = 4.6682E-05
# True
# Itr = 3, residual norm = 1.6914E-06
# True
# Itr = 4, residual norm = 6.2042E-08
# True
# Itr = 5, residual norm = 2.2500E-09
# True
# Itr = 6, residual norm = 8.2530E-11
# Time = 0.0613333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.7941E-02
# True
# Itr = 1, residual norm = 1.2799E-03
# True
# Itr = 2, residual norm = 4.6821E-05
# True
# Itr = 3, residual norm = 1.7074E-06
# True
# Itr = 4, residual norm = 6.3068E-08
# True
# Itr = 5, residual norm = 2.3021E-09
# True
# Itr = 6, residual norm = 8.5034E-11
# Time = 0.06266666666666663, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.7711E-02
# True
# Itr = 1, residual norm = 1.2758E-03
# True
# Itr = 2, residual norm = 4.6990E-05
# True
# Itr = 3, residual norm = 1.7255E-06
# True
# Itr = 4, residual norm = 6.4205E-08
# True
# Itr = 5, residual norm = 2.3599E-09
# True
# Itr = 6, residual norm = 8.7818E-11
# Time = 0.06399999999999997, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.7483E-02
# True
# Itr = 1, residual norm = 1.2721E-03
# True
# Itr = 2, residual norm = 4.7189E-05
# True
# Itr = 3, residual norm = 1.7455E-06
# True
# Itr = 4, residual norm = 6.5456E-08
# True
# Itr = 5, residual norm = 2.4236E-09
# True
# Itr = 6, residual norm = 9.0894E-11
# Time = 0.06533333333333331, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.7256E-02
# True
# Itr = 1, residual norm = 1.2687E-03
# True
# Itr = 2, residual norm = 4.7416E-05
# True
# Itr = 3, residual norm = 1.7675E-06
# True
# Itr = 4, residual norm = 6.6822E-08
# True
# Itr = 5, residual norm = 2.4934E-09
# True
# Itr = 6, residual norm = 9.4278E-11
# Time = 0.06666666666666665, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.7031E-02
# True
# Itr = 1, residual norm = 1.2655E-03
# True
# Itr = 2, residual norm = 4.7671E-05
# True
# Itr = 3, residual norm = 1.7914E-06
# True
# Itr = 4, residual norm = 6.8302E-08
# True
# Itr = 5, residual norm = 2.5693E-09
# True
# Itr = 6, residual norm = 9.7980E-11
# Time = 0.06799999999999999, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.6807E-02
# True
# Itr = 1, residual norm = 1.2626E-03
# True
# Itr = 2, residual norm = 4.7953E-05
# True
# Itr = 3, residual norm = 1.8172E-06
# True
# Itr = 4, residual norm = 6.9897E-08
# True
# Itr = 5, residual norm = 2.6515E-09
# True
# Itr = 6, residual norm = 1.0201E-10
# Time = 0.06933333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.6586E-02
# True
# Itr = 1, residual norm = 1.2600E-03
# True
# Itr = 2, residual norm = 4.8259E-05
# True
# Itr = 3, residual norm = 1.8448E-06
# True
# Itr = 4, residual norm = 7.1607E-08
# True
# Itr = 5, residual norm = 2.7402E-09
# True
# Itr = 6, residual norm = 1.0639E-10
# Time = 0.07066666666666667, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.6367E-02
# True
# Itr = 1, residual norm = 1.2577E-03
# True
# Itr = 2, residual norm = 4.8589E-05
# True
# Itr = 3, residual norm = 1.8742E-06
# True
# Itr = 4, residual norm = 7.3430E-08
# True
# Itr = 5, residual norm = 2.8353E-09
# True
# Itr = 6, residual norm = 1.1112E-10
# Time = 0.07200000000000001, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.6151E-02
# True
# Itr = 1, residual norm = 1.2555E-03
# True
# Itr = 2, residual norm = 4.8941E-05
# True
# Itr = 3, residual norm = 1.9053E-06
# True
# Itr = 4, residual norm = 7.5366E-08
# True
# Itr = 5, residual norm = 2.9372E-09
# True
# Itr = 6, residual norm = 1.1622E-10
# Time = 0.07333333333333335, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5939E-02
# True
# Itr = 1, residual norm = 1.2536E-03
# True
# Itr = 2, residual norm = 4.9315E-05
# True
# Itr = 3, residual norm = 1.9382E-06
# True
# Itr = 4, residual norm = 7.7415E-08
# True
# Itr = 5, residual norm = 3.0458E-09
# True
# Itr = 6, residual norm = 1.2171E-10
# Time = 0.07466666666666669, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5731E-02
# True
# Itr = 1, residual norm = 1.2520E-03
# True
# Itr = 2, residual norm = 4.9709E-05
# True
# Itr = 3, residual norm = 1.9727E-06
# True
# Itr = 4, residual norm = 7.9575E-08
# True
# Itr = 5, residual norm = 3.1612E-09
# True
# Itr = 6, residual norm = 1.2758E-10
# Time = 0.07600000000000003, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5527E-02
# True
# Itr = 1, residual norm = 1.2506E-03
# True
# Itr = 2, residual norm = 5.0123E-05
# True
# Itr = 3, residual norm = 2.0088E-06
# True
# Itr = 4, residual norm = 8.1847E-08
# True
# Itr = 5, residual norm = 3.2836E-09
# True
# Itr = 6, residual norm = 1.3386E-10
# Time = 0.07733333333333337, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5327E-02
# True
# Itr = 1, residual norm = 1.2494E-03
# True
# Itr = 2, residual norm = 5.0555E-05
# True
# Itr = 3, residual norm = 2.0465E-06
# True
# Itr = 4, residual norm = 8.4230E-08
# True
# Itr = 5, residual norm = 3.4131E-09
# True
# Itr = 6, residual norm = 1.4056E-10
# Time = 0.0786666666666667, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5133E-02
# True
# Itr = 1, residual norm = 1.2485E-03
# True
# Itr = 2, residual norm = 5.1006E-05
# True
# Itr = 3, residual norm = 2.0857E-06
# True
# Itr = 4, residual norm = 8.6724E-08
# True
# Itr = 5, residual norm = 3.5498E-09
# True
# Itr = 6, residual norm = 1.4770E-10
# Time = 0.08000000000000004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4945E-02
# True
# Itr = 1, residual norm = 1.2478E-03
# True
# Itr = 2, residual norm = 5.1476E-05
# True
# Itr = 3, residual norm = 2.1266E-06
# True
# Itr = 4, residual norm = 8.9332E-08
# True
# Itr = 5, residual norm = 3.6941E-09
# True
# Itr = 6, residual norm = 1.5529E-10
# Time = 0.08133333333333338, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4763E-02
# True
# Itr = 1, residual norm = 1.2474E-03
# True
# Itr = 2, residual norm = 5.1965E-05
# True
# Itr = 3, residual norm = 2.1691E-06
# True
# Itr = 4, residual norm = 9.2056E-08
# True
# Itr = 5, residual norm = 3.8461E-09
# True
# Itr = 6, residual norm = 1.6335E-10
# Time = 0.08266666666666672, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4589E-02
# True
# Itr = 1, residual norm = 1.2474E-03
# True
# Itr = 2, residual norm = 5.2474E-05
# True
# Itr = 3, residual norm = 2.2133E-06
# True
# Itr = 4, residual norm = 9.4900E-08
# True
# Itr = 5, residual norm = 4.0064E-09
# True
# Itr = 6, residual norm = 1.7192E-10
# Time = 0.08400000000000006, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4421E-02
# True
# Itr = 1, residual norm = 1.2477E-03
# True
# Itr = 2, residual norm = 5.3004E-05
# True
# Itr = 3, residual norm = 2.2592E-06
# True
# Itr = 4, residual norm = 9.7871E-08
# True
# Itr = 5, residual norm = 4.1752E-09
# True
# Itr = 6, residual norm = 1.8103E-10
# Time = 0.0853333333333334, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4262E-02
# True
# Itr = 1, residual norm = 1.2483E-03
# True
# Itr = 2, residual norm = 5.3557E-05
# True
# Itr = 3, residual norm = 2.3070E-06
# True
# Itr = 4, residual norm = 1.0097E-07
# True
# Itr = 5, residual norm = 4.3531E-09
# True
# Itr = 6, residual norm = 1.9071E-10
# Time = 0.08666666666666674, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4111E-02
# True
# Itr = 1, residual norm = 1.2494E-03
# True
# Itr = 2, residual norm = 5.4135E-05
# True
# Itr = 3, residual norm = 2.3568E-06
# True
# Itr = 4, residual norm = 1.0422E-07
# True
# Itr = 5, residual norm = 4.5408E-09
# True
# Itr = 6, residual norm = 2.0099E-10
# Time = 0.08800000000000008, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3969E-02
# True
# Itr = 1, residual norm = 1.2509E-03
# True
# Itr = 2, residual norm = 5.4739E-05
# True
# Itr = 3, residual norm = 2.4087E-06
# True
# Itr = 4, residual norm = 1.0761E-07
# True
# Itr = 5, residual norm = 4.7387E-09
# True
# Itr = 6, residual norm = 2.1192E-10
# Time = 0.08933333333333342, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3836E-02
# True
# Itr = 1, residual norm = 1.2529E-03
# True
# Itr = 2, residual norm = 5.5371E-05
# True
# Itr = 3, residual norm = 2.4628E-06
# True
# Itr = 4, residual norm = 1.1116E-07
# True
# Itr = 5, residual norm = 4.9474E-09
# True
# Itr = 6, residual norm = 2.2355E-10
# Time = 0.09066666666666676, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3714E-02
# True
# Itr = 1, residual norm = 1.2554E-03
# True
# Itr = 2, residual norm = 5.6032E-05
# True
# Itr = 3, residual norm = 2.5191E-06
# True
# Itr = 4, residual norm = 1.1487E-07
# True
# Itr = 5, residual norm = 5.1674E-09
# True
# Itr = 6, residual norm = 2.3590E-10
# Time = 0.0920000000000001, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3601E-02
# True
# Itr = 1, residual norm = 1.2585E-03
# True
# Itr = 2, residual norm = 5.6722E-05
# True
# Itr = 3, residual norm = 2.5778E-06
# True
# Itr = 4, residual norm = 1.1874E-07
# True
# Itr = 5, residual norm = 5.3991E-09
# True
# Itr = 6, residual norm = 2.4900E-10
# Time = 0.09333333333333343, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3500E-02
# True
# Itr = 1, residual norm = 1.2620E-03
# True
# Itr = 2, residual norm = 5.7442E-05
# True
# Itr = 3, residual norm = 2.6387E-06
# True
# Itr = 4, residual norm = 1.2277E-07
# True
# Itr = 5, residual norm = 5.6425E-09
# True
# Itr = 6, residual norm = 2.6287E-10
# Time = 0.09466666666666677, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3409E-02
# True
# Itr = 1, residual norm = 1.2662E-03
# True
# Itr = 2, residual norm = 5.8190E-05
# True
# Itr = 3, residual norm = 2.7018E-06
# True
# Itr = 4, residual norm = 1.2696E-07
# True
# Itr = 5, residual norm = 5.8977E-09
# True
# Itr = 6, residual norm = 2.7751E-10
# Time = 0.09600000000000011, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3329E-02
# True
# Itr = 1, residual norm = 1.2708E-03
# True
# Itr = 2, residual norm = 5.8965E-05
# True
# Itr = 3, residual norm = 2.7670E-06
# True
# Itr = 4, residual norm = 1.3130E-07
# True
# Itr = 5, residual norm = 6.1640E-09
# True
# Itr = 6, residual norm = 2.9292E-10
# Time = 0.09733333333333345, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3261E-02
# True
# Itr = 1, residual norm = 1.2760E-03
# True
# Itr = 2, residual norm = 5.9763E-05
# True
# Itr = 3, residual norm = 2.8340E-06
# True
# Itr = 4, residual norm = 1.3578E-07
# True
# Itr = 5, residual norm = 6.4407E-09
# True
# Itr = 6, residual norm = 3.0903E-10
# Time = 0.09866666666666679, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3205E-02
# True
# Itr = 1, residual norm = 1.2817E-03
# True
# Itr = 2, residual norm = 6.0581E-05
# True
# Itr = 3, residual norm = 2.9024E-06
# True
# Itr = 4, residual norm = 1.4036E-07
# True
# Itr = 5, residual norm = 6.7267E-09
# True
# Itr = 6, residual norm = 3.2580E-10
# Time = 0.10000000000000013, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3161E-02
# True
# Itr = 1, residual norm = 1.2878E-03
# True
# Itr = 2, residual norm = 6.1414E-05
# True
# Itr = 3, residual norm = 2.9720E-06
# True
# Itr = 4, residual norm = 1.4503E-07
# True
# Itr = 5, residual norm = 7.0200E-09
# True
# Itr = 6, residual norm = 3.4311E-10
# True
# Itr = 7, residual norm = 1.6584E-11
# Time = 0.10133333333333347, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3129E-02
# True
# Itr = 1, residual norm = 1.2944E-03
# True
# Itr = 2, residual norm = 6.2256E-05
# True
# Itr = 3, residual norm = 3.0421E-06
# True
# Itr = 4, residual norm = 1.4974E-07
# True
# Itr = 5, residual norm = 7.3184E-09
# True
# Itr = 6, residual norm = 3.6082E-10
# True
# Itr = 7, residual norm = 1.7609E-11
# Time = 0.10266666666666681, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3109E-02
# True
# Itr = 1, residual norm = 1.3013E-03
# True
# Itr = 2, residual norm = 6.3100E-05
# True
# Itr = 3, residual norm = 3.1122E-06
# True
# Itr = 4, residual norm = 1.5446E-07
# True
# Itr = 5, residual norm = 7.6191E-09
# True
# Itr = 6, residual norm = 3.7876E-10
# True
# Itr = 7, residual norm = 1.8655E-11
# Time = 0.10400000000000015, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3100E-02
# True
# Itr = 1, residual norm = 1.3086E-03
# True
# Itr = 2, residual norm = 6.3939E-05
# True
# Itr = 3, residual norm = 3.1816E-06
# True
# Itr = 4, residual norm = 1.5912E-07
# True
# Itr = 5, residual norm = 7.9186E-09
# True
# Itr = 6, residual norm = 3.9671E-10
# True
# Itr = 7, residual norm = 1.9711E-11
# Time = 0.10533333333333349, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3105E-02
# True
# Itr = 1, residual norm = 1.3162E-03
# True
# Itr = 2, residual norm = 6.4764E-05
# True
# Itr = 3, residual norm = 3.2495E-06
# True
# Itr = 4, residual norm = 1.6368E-07
# True
# Itr = 5, residual norm = 8.2131E-09
# True
# Itr = 6, residual norm = 4.1443E-10
# True
# Itr = 7, residual norm = 2.0761E-11
# Time = 0.10666666666666683, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3121E-02
# True
# Itr = 1, residual norm = 1.3240E-03
# True
# Itr = 2, residual norm = 6.5568E-05
# True
# Itr = 3, residual norm = 3.3152E-06
# True
# Itr = 4, residual norm = 1.6808E-07
# True
# Itr = 5, residual norm = 8.4985E-09
# True
# Itr = 6, residual norm = 4.3164E-10
# True
# Itr = 7, residual norm = 2.1789E-11
# Time = 0.10800000000000017, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3148E-02
# True
# Itr = 1, residual norm = 1.3319E-03
# True
# Itr = 2, residual norm = 6.6343E-05
# True
# Itr = 3, residual norm = 3.3780E-06
# True
# Itr = 4, residual norm = 1.7226E-07
# True
# Itr = 5, residual norm = 8.7710E-09
# True
# Itr = 6, residual norm = 4.4809E-10
# True
# Itr = 7, residual norm = 2.2777E-11
# Time = 0.1093333333333335, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3188E-02
# True
# Itr = 1, residual norm = 1.3399E-03
# True
# Itr = 2, residual norm = 6.7082E-05
# True
# Itr = 3, residual norm = 3.4373E-06
# True
# Itr = 4, residual norm = 1.7618E-07
# True
# Itr = 5, residual norm = 9.0270E-09
# True
# Itr = 6, residual norm = 4.6353E-10
# True
# Itr = 7, residual norm = 2.3710E-11
# Time = 0.11066666666666684, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3238E-02
# True
# Itr = 1, residual norm = 1.3479E-03
# True
# Itr = 2, residual norm = 6.7782E-05
# True
# Itr = 3, residual norm = 3.4925E-06
# True
# Itr = 4, residual norm = 1.7980E-07
# True
# Itr = 5, residual norm = 9.2636E-09
# True
# Itr = 6, residual norm = 4.7777E-10
# True
# Itr = 7, residual norm = 2.4574E-11
# Time = 0.11200000000000018, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3299E-02
# True
# Itr = 1, residual norm = 1.3560E-03
# True
# Itr = 2, residual norm = 6.8441E-05
# True
# Itr = 3, residual norm = 3.5436E-06
# True
# Itr = 4, residual norm = 1.8309E-07
# True
# Itr = 5, residual norm = 9.4789E-09
# True
# Itr = 6, residual norm = 4.9066E-10
# True
# Itr = 7, residual norm = 2.5359E-11
# Time = 0.11333333333333352, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3371E-02
# True
# Itr = 1, residual norm = 1.3641E-03
# True
# Itr = 2, residual norm = 6.9057E-05
# True
# Itr = 3, residual norm = 3.5901E-06
# True
# Itr = 4, residual norm = 1.8604E-07
# True
# Itr = 5, residual norm = 9.6715E-09
# True
# Itr = 6, residual norm = 5.0212E-10
# True
# Itr = 7, residual norm = 2.6057E-11
# Time = 0.11466666666666686, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3452E-02
# True
# Itr = 1, residual norm = 1.3722E-03
# True
# Itr = 2, residual norm = 6.9632E-05
# True
# Itr = 3, residual norm = 3.6323E-06
# True
# Itr = 4, residual norm = 1.8866E-07
# True
# Itr = 5, residual norm = 9.8407E-09
# True
# Itr = 6, residual norm = 5.1207E-10
# True
# Itr = 7, residual norm = 2.6664E-11
# Time = 0.1160000000000002, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3543E-02
# True
# Itr = 1, residual norm = 1.3802E-03
# True
# Itr = 2, residual norm = 7.0165E-05
# True
# Itr = 3, residual norm = 3.6699E-06
# True
# Itr = 4, residual norm = 1.9092E-07
# True
# Itr = 5, residual norm = 9.9859E-09
# True
# Itr = 6, residual norm = 5.2047E-10
# True
# Itr = 7, residual norm = 2.7175E-11
# Time = 0.11733333333333354, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3642E-02
# True
# Itr = 1, residual norm = 1.3883E-03
# True
# Itr = 2, residual norm = 7.0656E-05
# True
# Itr = 3, residual norm = 3.7030E-06
# True
# Itr = 4, residual norm = 1.9284E-07
# True
# Itr = 5, residual norm = 1.0106E-08
# True
# Itr = 6, residual norm = 5.2728E-10
# True
# Itr = 7, residual norm = 2.7586E-11
# Time = 0.11866666666666688, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3748E-02
# True
# Itr = 1, residual norm = 1.3963E-03
# True
# Itr = 2, residual norm = 7.1104E-05
# True
# Itr = 3, residual norm = 3.7314E-06
# True
# Itr = 4, residual norm = 1.9439E-07
# True
# Itr = 5, residual norm = 1.0201E-08
# True
# Itr = 6, residual norm = 5.3243E-10
# True
# Itr = 7, residual norm = 2.7893E-11
# Time = 0.12000000000000022, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3861E-02
# True
# Itr = 1, residual norm = 1.4042E-03
# True
# Itr = 2, residual norm = 7.1506E-05
# True
# Itr = 3, residual norm = 3.7548E-06
# True
# Itr = 4, residual norm = 1.9557E-07
# True
# Itr = 5, residual norm = 1.0270E-08
# True
# Itr = 6, residual norm = 5.3585E-10
# True
# Itr = 7, residual norm = 2.8091E-11
# Time = 0.12133333333333356, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.3980E-02
# True
# Itr = 1, residual norm = 1.4120E-03
# True
# Itr = 2, residual norm = 7.1859E-05
# True
# Itr = 3, residual norm = 3.7729E-06
# True
# Itr = 4, residual norm = 1.9634E-07
# True
# Itr = 5, residual norm = 1.0310E-08
# True
# Itr = 6, residual norm = 5.3747E-10
# True
# Itr = 7, residual norm = 2.8175E-11
# Time = 0.1226666666666669, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4104E-02
# True
# Itr = 1, residual norm = 1.4196E-03
# True
# Itr = 2, residual norm = 7.2159E-05
# True
# Itr = 3, residual norm = 3.7856E-06
# True
# Itr = 4, residual norm = 1.9672E-07
# True
# Itr = 5, residual norm = 1.0321E-08
# True
# Itr = 6, residual norm = 5.3727E-10
# True
# Itr = 7, residual norm = 2.8143E-11
# Time = 0.12400000000000024, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4232E-02
# True
# Itr = 1, residual norm = 1.4269E-03
# True
# Itr = 2, residual norm = 7.2405E-05
# True
# Itr = 3, residual norm = 3.7928E-06
# True
# Itr = 4, residual norm = 1.9669E-07
# True
# Itr = 5, residual norm = 1.0305E-08
# True
# Itr = 6, residual norm = 5.3533E-10
# True
# Itr = 7, residual norm = 2.8002E-11
# Time = 0.12533333333333357, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4363E-02
# True
# Itr = 1, residual norm = 1.4339E-03
# True
# Itr = 2, residual norm = 7.2601E-05
# True
# Itr = 3, residual norm = 3.7950E-06
# True
# Itr = 4, residual norm = 1.9632E-07
# True
# Itr = 5, residual norm = 1.0264E-08
# True
# Itr = 6, residual norm = 5.3183E-10
# True
# Itr = 7, residual norm = 2.7762E-11
# Time = 0.1266666666666669, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4495E-02
# True
# Itr = 1, residual norm = 1.4406E-03
# True
# Itr = 2, residual norm = 7.2752E-05
# True
# Itr = 3, residual norm = 3.7930E-06
# True
# Itr = 4, residual norm = 1.9565E-07
# True
# Itr = 5, residual norm = 1.0202E-08
# True
# Itr = 6, residual norm = 5.2711E-10
# True
# Itr = 7, residual norm = 2.7445E-11
# Time = 0.12800000000000022, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4627E-02
# True
# Itr = 1, residual norm = 1.4470E-03
# True
# Itr = 2, residual norm = 7.2873E-05
# True
# Itr = 3, residual norm = 3.7879E-06
# True
# Itr = 4, residual norm = 1.9478E-07
# True
# Itr = 5, residual norm = 1.0128E-08
# True
# Itr = 6, residual norm = 5.2160E-10
# True
# Itr = 7, residual norm = 2.7080E-11
# Time = 0.12933333333333355, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4758E-02
# True
# Itr = 1, residual norm = 1.4531E-03
# True
# Itr = 2, residual norm = 7.2976E-05
# True
# Itr = 3, residual norm = 3.7813E-06
# True
# Itr = 4, residual norm = 1.9383E-07
# True
# Itr = 5, residual norm = 1.0047E-08
# True
# Itr = 6, residual norm = 5.1580E-10
# True
# Itr = 7, residual norm = 2.6696E-11
# Time = 0.13066666666666688, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4886E-02
# True
# Itr = 1, residual norm = 1.4590E-03
# True
# Itr = 2, residual norm = 7.3078E-05
# True
# Itr = 3, residual norm = 3.7747E-06
# True
# Itr = 4, residual norm = 1.9292E-07
# True
# Itr = 5, residual norm = 9.9680E-09
# True
# Itr = 6, residual norm = 5.1021E-10
# True
# Itr = 7, residual norm = 2.6326E-11
# Time = 0.1320000000000002, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5010E-02
# True
# Itr = 1, residual norm = 1.4648E-03
# True
# Itr = 2, residual norm = 7.3194E-05
# True
# Itr = 3, residual norm = 3.7694E-06
# True
# Itr = 4, residual norm = 1.9213E-07
# True
# Itr = 5, residual norm = 9.8980E-09
# True
# Itr = 6, residual norm = 5.0525E-10
# True
# Itr = 7, residual norm = 2.5994E-11
# Time = 0.13333333333333353, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5128E-02
# True
# Itr = 1, residual norm = 1.4706E-03
# True
# Itr = 2, residual norm = 7.3335E-05
# True
# Itr = 3, residual norm = 3.7666E-06
# True
# Itr = 4, residual norm = 1.9155E-07
# True
# Itr = 5, residual norm = 9.8418E-09
# True
# Itr = 6, residual norm = 5.0123E-10
# True
# Itr = 7, residual norm = 2.5719E-11
# Time = 0.13466666666666685, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5241E-02
# True
# Itr = 1, residual norm = 1.4764E-03
# True
# Itr = 2, residual norm = 7.3512E-05
# True
# Itr = 3, residual norm = 3.7670E-06
# True
# Itr = 4, residual norm = 1.9124E-07
# True
# Itr = 5, residual norm = 9.8032E-09
# True
# Itr = 6, residual norm = 4.9837E-10
# True
# Itr = 7, residual norm = 2.5514E-11
# Time = 0.13600000000000018, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5346E-02
# True
# Itr = 1, residual norm = 1.4822E-03
# True
# Itr = 2, residual norm = 7.3733E-05
# True
# Itr = 3, residual norm = 3.7715E-06
# True
# Itr = 4, residual norm = 1.9123E-07
# True
# Itr = 5, residual norm = 9.7851E-09
# True
# Itr = 6, residual norm = 4.9683E-10
# True
# Itr = 7, residual norm = 2.5390E-11
# Time = 0.1373333333333335, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5442E-02
# True
# Itr = 1, residual norm = 1.4882E-03
# True
# Itr = 2, residual norm = 7.4006E-05
# True
# Itr = 3, residual norm = 3.7807E-06
# True
# Itr = 4, residual norm = 1.9159E-07
# True
# Itr = 5, residual norm = 9.7912E-09
# True
# Itr = 6, residual norm = 4.9685E-10
# True
# Itr = 7, residual norm = 2.5359E-11
# Time = 0.13866666666666683, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5530E-02
# True
# Itr = 1, residual norm = 1.4944E-03
# True
# Itr = 2, residual norm = 7.4345E-05
# True
# Itr = 3, residual norm = 3.7959E-06
# True
# Itr = 4, residual norm = 1.9240E-07
# True
# Itr = 5, residual norm = 9.8266E-09
# True
# Itr = 6, residual norm = 4.9874E-10
# True
# Itr = 7, residual norm = 2.5441E-11
# Time = 0.14000000000000015, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5607E-02
# True
# Itr = 1, residual norm = 1.5010E-03
# True
# Itr = 2, residual norm = 7.4770E-05
# True
# Itr = 3, residual norm = 3.8186E-06
# True
# Itr = 4, residual norm = 1.9376E-07
# True
# Itr = 5, residual norm = 9.8987E-09
# True
# Itr = 6, residual norm = 5.0295E-10
# True
# Itr = 7, residual norm = 2.5663E-11
# Time = 0.14133333333333348, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5674E-02
# True
# Itr = 1, residual norm = 1.5082E-03
# True
# Itr = 2, residual norm = 7.5300E-05
# True
# Itr = 3, residual norm = 3.8506E-06
# True
# Itr = 4, residual norm = 1.9581E-07
# True
# Itr = 5, residual norm = 1.0016E-08
# True
# Itr = 6, residual norm = 5.1002E-10
# True
# Itr = 7, residual norm = 2.6056E-11
# Time = 0.1426666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5729E-02
# True
# Itr = 1, residual norm = 1.5159E-03
# True
# Itr = 2, residual norm = 7.5958E-05
# True
# Itr = 3, residual norm = 3.8938E-06
# True
# Itr = 4, residual norm = 1.9869E-07
# True
# Itr = 5, residual norm = 1.0188E-08
# True
# Itr = 6, residual norm = 5.2055E-10
# True
# Itr = 7, residual norm = 2.6659E-11
# Time = 0.14400000000000013, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5772E-02
# True
# Itr = 1, residual norm = 1.5245E-03
# True
# Itr = 2, residual norm = 7.6762E-05
# True
# Itr = 3, residual norm = 3.9498E-06
# True
# Itr = 4, residual norm = 2.0252E-07
# True
# Itr = 5, residual norm = 1.0423E-08
# True
# Itr = 6, residual norm = 5.3513E-10
# True
# Itr = 7, residual norm = 2.7507E-11
# Time = 0.14533333333333345, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5803E-02
# True
# Itr = 1, residual norm = 1.5340E-03
# True
# Itr = 2, residual norm = 7.7726E-05
# True
# Itr = 3, residual norm = 4.0200E-06
# True
# Itr = 4, residual norm = 2.0741E-07
# True
# Itr = 5, residual norm = 1.0728E-08
# True
# Itr = 6, residual norm = 5.5427E-10
# True
# Itr = 7, residual norm = 2.8635E-11
# Time = 0.14666666666666678, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5820E-02
# True
# Itr = 1, residual norm = 1.5444E-03
# True
# Itr = 2, residual norm = 7.8856E-05
# True
# Itr = 3, residual norm = 4.1051E-06
# True
# Itr = 4, residual norm = 2.1341E-07
# True
# Itr = 5, residual norm = 1.1110E-08
# True
# Itr = 6, residual norm = 5.7840E-10
# True
# Itr = 7, residual norm = 3.0074E-11
# Time = 0.1480000000000001, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5823E-02
# True
# Itr = 1, residual norm = 1.5557E-03
# True
# Itr = 2, residual norm = 8.0150E-05
# True
# Itr = 3, residual norm = 4.2052E-06
# True
# Itr = 4, residual norm = 2.2057E-07
# True
# Itr = 5, residual norm = 1.1572E-08
# True
# Itr = 6, residual norm = 6.0787E-10
# True
# Itr = 7, residual norm = 3.1851E-11
# Time = 0.14933333333333343, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5813E-02
# True
# Itr = 1, residual norm = 1.5679E-03
# True
# Itr = 2, residual norm = 8.1606E-05
# True
# Itr = 3, residual norm = 4.3204E-06
# True
# Itr = 4, residual norm = 2.2892E-07
# True
# Itr = 5, residual norm = 1.2118E-08
# True
# Itr = 6, residual norm = 6.4302E-10
# True
# Itr = 7, residual norm = 3.3993E-11
# Time = 0.15066666666666675, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5790E-02
# True
# Itr = 1, residual norm = 1.5810E-03
# True
# Itr = 2, residual norm = 8.3216E-05
# True
# Itr = 3, residual norm = 4.4506E-06
# True
# Itr = 4, residual norm = 2.3846E-07
# True
# Itr = 5, residual norm = 1.2751E-08
# True
# Itr = 6, residual norm = 6.8420E-10
# True
# Itr = 7, residual norm = 3.6534E-11
# Time = 0.15200000000000008, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5755E-02
# True
# Itr = 1, residual norm = 1.5949E-03
# True
# Itr = 2, residual norm = 8.4978E-05
# True
# Itr = 3, residual norm = 4.5958E-06
# True
# Itr = 4, residual norm = 2.4924E-07
# True
# Itr = 5, residual norm = 1.3475E-08
# True
# Itr = 6, residual norm = 7.3191E-10
# True
# Itr = 7, residual norm = 3.9514E-11
# Time = 0.1533333333333334, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5708E-02
# True
# Itr = 1, residual norm = 1.6096E-03
# True
# Itr = 2, residual norm = 8.6892E-05
# True
# Itr = 3, residual norm = 4.7566E-06
# True
# Itr = 4, residual norm = 2.6131E-07
# True
# Itr = 5, residual norm = 1.4298E-08
# True
# Itr = 6, residual norm = 7.8680E-10
# True
# Itr = 7, residual norm = 4.2987E-11
# Time = 0.15466666666666673, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5651E-02
# True
# Itr = 1, residual norm = 1.6251E-03
# True
# Itr = 2, residual norm = 8.8960E-05
# True
# Itr = 3, residual norm = 4.9336E-06
# True
# Itr = 4, residual norm = 2.7479E-07
# True
# Itr = 5, residual norm = 1.5231E-08
# True
# Itr = 6, residual norm = 8.4974E-10
# True
# Itr = 7, residual norm = 4.7025E-11
# Time = 0.15600000000000006, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5586E-02
# True
# Itr = 1, residual norm = 1.6416E-03
# True
# Itr = 2, residual norm = 9.1190E-05
# True
# Itr = 3, residual norm = 5.1279E-06
# True
# Itr = 4, residual norm = 2.8978E-07
# True
# Itr = 5, residual norm = 1.6284E-08
# True
# Itr = 6, residual norm = 9.2184E-10
# True
# Itr = 7, residual norm = 5.1717E-11
# Time = 0.15733333333333338, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5513E-02
# True
# Itr = 1, residual norm = 1.6591E-03
# True
# Itr = 2, residual norm = 9.3589E-05
# True
# Itr = 3, residual norm = 5.3409E-06
# True
# Itr = 4, residual norm = 3.0643E-07
# True
# Itr = 5, residual norm = 1.7473E-08
# True
# Itr = 6, residual norm = 1.0043E-09
# True
# Itr = 7, residual norm = 5.7168E-11
# Time = 0.1586666666666667, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5435E-02
# True
# Itr = 1, residual norm = 1.6777E-03
# True
# Itr = 2, residual norm = 9.6161E-05
# True
# Itr = 3, residual norm = 5.5733E-06
# True
# Itr = 4, residual norm = 3.2485E-07
# True
# Itr = 5, residual norm = 1.8809E-08
# True
# Itr = 6, residual norm = 1.0984E-09
# True
# Itr = 7, residual norm = 6.3485E-11
# Time = 0.16000000000000003, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5354E-02
# True
# Itr = 1, residual norm = 1.6974E-03
# True
# Itr = 2, residual norm = 9.8902E-05
# True
# Itr = 3, residual norm = 5.8253E-06
# True
# Itr = 4, residual norm = 3.4510E-07
# True
# Itr = 5, residual norm = 2.0303E-08
# True
# Itr = 6, residual norm = 1.2052E-09
# True
# Itr = 7, residual norm = 7.0769E-11
# Time = 0.16133333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5271E-02
# True
# Itr = 1, residual norm = 1.7181E-03
# True
# Itr = 2, residual norm = 1.0180E-04
# True
# Itr = 3, residual norm = 6.0958E-06
# True
# Itr = 4, residual norm = 3.6712E-07
# True
# Itr = 5, residual norm = 2.1956E-08
# True
# Itr = 6, residual norm = 1.3251E-09
# True
# Itr = 7, residual norm = 7.9087E-11
# Time = 0.16266666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5191E-02
# True
# Itr = 1, residual norm = 1.7398E-03
# True
# Itr = 2, residual norm = 1.0481E-04
# True
# Itr = 3, residual norm = 6.3823E-06
# True
# Itr = 4, residual norm = 3.9075E-07
# True
# Itr = 5, residual norm = 2.3759E-08
# True
# Itr = 6, residual norm = 1.4579E-09
# True
# Itr = 7, residual norm = 8.8456E-11
# Time = 0.164, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5114E-02
# True
# Itr = 1, residual norm = 1.7622E-03
# True
# Itr = 2, residual norm = 1.0791E-04
# True
# Itr = 3, residual norm = 6.6811E-06
# True
# Itr = 4, residual norm = 4.1567E-07
# True
# Itr = 5, residual norm = 2.5694E-08
# True
# Itr = 6, residual norm = 1.6024E-09
# True
# Itr = 7, residual norm = 9.8823E-11
# Time = 0.16533333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5044E-02
# True
# Itr = 1, residual norm = 1.7852E-03
# True
# Itr = 2, residual norm = 1.1104E-04
# True
# Itr = 3, residual norm = 6.9872E-06
# True
# Itr = 4, residual norm = 4.4148E-07
# True
# Itr = 5, residual norm = 2.7731E-08
# True
# Itr = 6, residual norm = 1.7565E-09
# True
# Itr = 7, residual norm = 1.1007E-10
# Time = 0.16666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4983E-02
# True
# Itr = 1, residual norm = 1.8084E-03
# True
# Itr = 2, residual norm = 1.1416E-04
# True
# Itr = 3, residual norm = 7.2961E-06
# True
# Itr = 4, residual norm = 4.6773E-07
# True
# Itr = 5, residual norm = 2.9836E-08
# True
# Itr = 6, residual norm = 1.9177E-09
# True
# Itr = 7, residual norm = 1.2202E-10
# Time = 0.16799999999999998, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4935E-02
# True
# Itr = 1, residual norm = 1.8318E-03
# True
# Itr = 2, residual norm = 1.1723E-04
# True
# Itr = 3, residual norm = 7.6037E-06
# True
# Itr = 4, residual norm = 4.9406E-07
# True
# Itr = 5, residual norm = 3.1979E-08
# True
# Itr = 6, residual norm = 2.0835E-09
# True
# Itr = 7, residual norm = 1.3450E-10
# Time = 0.1693333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4900E-02
# True
# Itr = 1, residual norm = 1.8553E-03
# True
# Itr = 2, residual norm = 1.2024E-04
# True
# Itr = 3, residual norm = 7.9078E-06
# True
# Itr = 4, residual norm = 5.2020E-07
# True
# Itr = 5, residual norm = 3.4136E-08
# True
# Itr = 6, residual norm = 2.2520E-09
# True
# Itr = 7, residual norm = 1.4737E-10
# Time = 0.17066666666666663, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4882E-02
# True
# Itr = 1, residual norm = 1.8789E-03
# True
# Itr = 2, residual norm = 1.2319E-04
# True
# Itr = 3, residual norm = 8.2079E-06
# True
# Itr = 4, residual norm = 5.4606E-07
# True
# Itr = 5, residual norm = 3.6298E-08
# True
# Itr = 6, residual norm = 2.4220E-09
# True
# Itr = 7, residual norm = 1.6053E-10
# Time = 0.17199999999999996, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4882E-02
# True
# Itr = 1, residual norm = 1.9029E-03
# True
# Itr = 2, residual norm = 1.2609E-04
# True
# Itr = 3, residual norm = 8.5043E-06
# True
# Itr = 4, residual norm = 5.7164E-07
# True
# Itr = 5, residual norm = 3.8461E-08
# True
# Itr = 6, residual norm = 2.5931E-09
# True
# Itr = 7, residual norm = 1.7394E-10
# Time = 0.17333333333333328, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4903E-02
# True
# Itr = 1, residual norm = 1.9274E-03
# True
# Itr = 2, residual norm = 1.2896E-04
# True
# Itr = 3, residual norm = 8.7973E-06
# True
# Itr = 4, residual norm = 5.9690E-07
# True
# Itr = 5, residual norm = 4.0617E-08
# True
# Itr = 6, residual norm = 2.7645E-09
# True
# Itr = 7, residual norm = 1.8754E-10
# Time = 0.1746666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.4945E-02
# True
# Itr = 1, residual norm = 1.9525E-03
# True
# Itr = 2, residual norm = 1.3178E-04
# True
# Itr = 3, residual norm = 9.0856E-06
# True
# Itr = 4, residual norm = 6.2167E-07
# True
# Itr = 5, residual norm = 4.2750E-08
# True
# Itr = 6, residual norm = 2.9345E-09
# True
# Itr = 7, residual norm = 2.0115E-10
# Time = 0.17599999999999993, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5011E-02
# True
# Itr = 1, residual norm = 1.9780E-03
# True
# Itr = 2, residual norm = 1.3454E-04
# True
# Itr = 3, residual norm = 9.3655E-06
# True
# Itr = 4, residual norm = 6.4559E-07
# True
# Itr = 5, residual norm = 4.4822E-08
# True
# Itr = 6, residual norm = 3.0997E-09
# True
# Itr = 7, residual norm = 2.1451E-10
# Time = 0.17733333333333326, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5101E-02
# True
# Itr = 1, residual norm = 2.0039E-03
# True
# Itr = 2, residual norm = 1.3719E-04
# True
# Itr = 3, residual norm = 9.6323E-06
# True
# Itr = 4, residual norm = 6.6814E-07
# True
# Itr = 5, residual norm = 4.6785E-08
# True
# Itr = 6, residual norm = 3.2558E-09
# True
# Itr = 7, residual norm = 2.2723E-10
# Time = 0.17866666666666658, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5216E-02
# True
# Itr = 1, residual norm = 2.0298E-03
# True
# Itr = 2, residual norm = 1.3970E-04
# True
# Itr = 3, residual norm = 9.8810E-06
# True
# Itr = 4, residual norm = 6.8884E-07
# True
# Itr = 5, residual norm = 4.8589E-08
# True
# Itr = 6, residual norm = 3.3984E-09
# True
# Itr = 7, residual norm = 2.3893E-10
# Time = 0.1799999999999999, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.5357E-02
# True
# Itr = 1, residual norm = 2.0556E-03
# True
# Itr = 2, residual norm = 1.4206E-04
# True
# Itr = 3, residual norm = 1.0109E-05
# True
# Itr = 4, residual norm = 7.0744E-07
# True
# Itr = 5, residual norm = 5.0208E-08
# True
# Itr = 6, residual norm = 3.5250E-09
# True
# Itr = 7, residual norm = 2.4935E-10
# ...
# Itr = 5, residual norm = 8.9953E-11
# Time = 1.9360000000000424, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9401E-03
# True
# Itr = 1, residual norm = 1.6722E-04
# True
# Itr = 2, residual norm = 4.4460E-06
# True
# Itr = 3, residual norm = 1.2096E-07
# True
# Itr = 4, residual norm = 3.2560E-09
# True
# Itr = 5, residual norm = 8.8759E-11
# Time = 1.9373333333333758, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9670E-03
# True
# Itr = 1, residual norm = 1.6770E-04
# True
# Itr = 2, residual norm = 4.4477E-06
# True
# Itr = 3, residual norm = 1.2056E-07
# True
# Itr = 4, residual norm = 3.2360E-09
# True
# Itr = 5, residual norm = 8.7889E-11
# Time = 1.9386666666667092, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9920E-03
# True
# Itr = 1, residual norm = 1.6824E-04
# True
# Itr = 2, residual norm = 4.4546E-06
# True
# Itr = 3, residual norm = 1.2041E-07
# True
# Itr = 4, residual norm = 3.2255E-09
# True
# Itr = 5, residual norm = 8.7356E-11
# Time = 1.9400000000000426, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0150E-03
# True
# Itr = 1, residual norm = 1.6883E-04
# True
# Itr = 2, residual norm = 4.4670E-06
# True
# Itr = 3, residual norm = 1.2051E-07
# True
# Itr = 4, residual norm = 3.2249E-09
# True
# Itr = 5, residual norm = 8.7174E-11
# Time = 1.941333333333376, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0360E-03
# True
# Itr = 1, residual norm = 1.6950E-04
# True
# Itr = 2, residual norm = 4.4853E-06
# True
# Itr = 3, residual norm = 1.2089E-07
# True
# Itr = 4, residual norm = 3.2346E-09
# True
# Itr = 5, residual norm = 8.7353E-11
# Time = 1.9426666666667094, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0549E-03
# True
# Itr = 1, residual norm = 1.7024E-04
# True
# Itr = 2, residual norm = 4.5097E-06
# True
# Itr = 3, residual norm = 1.2155E-07
# True
# Itr = 4, residual norm = 3.2550E-09
# True
# Itr = 5, residual norm = 8.7905E-11
# Time = 1.9440000000000428, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0716E-03
# True
# Itr = 1, residual norm = 1.7105E-04
# True
# Itr = 2, residual norm = 4.5403E-06
# True
# Itr = 3, residual norm = 1.2250E-07
# True
# Itr = 4, residual norm = 3.2864E-09
# True
# Itr = 5, residual norm = 8.8842E-11
# Time = 1.9453333333333762, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0860E-03
# True
# Itr = 1, residual norm = 1.7193E-04
# True
# Itr = 2, residual norm = 4.5773E-06
# True
# Itr = 3, residual norm = 1.2373E-07
# True
# Itr = 4, residual norm = 3.3291E-09
# True
# Itr = 5, residual norm = 9.0173E-11
# Time = 1.9466666666667096, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0983E-03
# True
# Itr = 1, residual norm = 1.7288E-04
# True
# Itr = 2, residual norm = 4.6206E-06
# True
# Itr = 3, residual norm = 1.2527E-07
# True
# Itr = 4, residual norm = 3.3832E-09
# True
# Itr = 5, residual norm = 9.1910E-11
# Time = 1.948000000000043, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1082E-03
# True
# Itr = 1, residual norm = 1.7390E-04
# True
# Itr = 2, residual norm = 4.6700E-06
# True
# Itr = 3, residual norm = 1.2710E-07
# True
# Itr = 4, residual norm = 3.4489E-09
# True
# Itr = 5, residual norm = 9.4060E-11
# Time = 1.9493333333333764, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1158E-03
# True
# Itr = 1, residual norm = 1.7497E-04
# True
# Itr = 2, residual norm = 4.7253E-06
# True
# Itr = 3, residual norm = 1.2921E-07
# True
# Itr = 4, residual norm = 3.5262E-09
# True
# Itr = 5, residual norm = 9.6631E-11
# Time = 1.9506666666667098, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1212E-03
# True
# Itr = 1, residual norm = 1.7608E-04
# True
# Itr = 2, residual norm = 4.7862E-06
# True
# Itr = 3, residual norm = 1.3161E-07
# True
# Itr = 4, residual norm = 3.6152E-09
# True
# Itr = 5, residual norm = 9.9628E-11
# Time = 1.9520000000000433, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1242E-03
# True
# Itr = 1, residual norm = 1.7723E-04
# True
# Itr = 2, residual norm = 4.8522E-06
# True
# Itr = 3, residual norm = 1.3428E-07
# True
# Itr = 4, residual norm = 3.7155E-09
# True
# Itr = 5, residual norm = 1.0305E-10
# True
# Itr = 6, residual norm = 2.8510E-12
# Time = 1.9533333333333767, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1249E-03
# True
# Itr = 1, residual norm = 1.7839E-04
# True
# Itr = 2, residual norm = 4.9228E-06
# True
# Itr = 3, residual norm = 1.3721E-07
# True
# Itr = 4, residual norm = 3.8270E-09
# True
# Itr = 5, residual norm = 1.0691E-10
# True
# Itr = 6, residual norm = 2.9814E-12
# Time = 1.95466666666671, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1234E-03
# True
# Itr = 1, residual norm = 1.7957E-04
# True
# Itr = 2, residual norm = 4.9975E-06
# True
# Itr = 3, residual norm = 1.4037E-07
# True
# Itr = 4, residual norm = 3.9492E-09
# True
# Itr = 5, residual norm = 1.1118E-10
# True
# Itr = 6, residual norm = 3.1276E-12
# Time = 1.9560000000000435, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1196E-03
# True
# Itr = 1, residual norm = 1.8074E-04
# True
# Itr = 2, residual norm = 5.0754E-06
# True
# Itr = 3, residual norm = 1.4374E-07
# True
# Itr = 4, residual norm = 4.0816E-09
# True
# Itr = 5, residual norm = 1.1587E-10
# True
# Itr = 6, residual norm = 3.2898E-12
# Time = 1.957333333333377, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1136E-03
# True
# Itr = 1, residual norm = 1.8188E-04
# True
# Itr = 2, residual norm = 5.1559E-06
# True
# Itr = 3, residual norm = 1.4731E-07
# True
# Itr = 4, residual norm = 4.2236E-09
# True
# Itr = 5, residual norm = 1.2097E-10
# True
# Itr = 6, residual norm = 3.4679E-12
# Time = 1.9586666666667103, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.1055E-03
# True
# Itr = 1, residual norm = 1.8298E-04
# True
# Itr = 2, residual norm = 5.2382E-06
# True
# Itr = 3, residual norm = 1.5104E-07
# True
# Itr = 4, residual norm = 4.3744E-09
# True
# Itr = 5, residual norm = 1.2645E-10
# True
# Itr = 6, residual norm = 3.6616E-12
# Time = 1.9600000000000437, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0953E-03
# True
# Itr = 1, residual norm = 1.8404E-04
# True
# Itr = 2, residual norm = 5.3216E-06
# True
# Itr = 3, residual norm = 1.5490E-07
# True
# Itr = 4, residual norm = 4.5331E-09
# True
# Itr = 5, residual norm = 1.3229E-10
# True
# Itr = 6, residual norm = 3.8708E-12
# Time = 1.9613333333333771, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0831E-03
# True
# Itr = 1, residual norm = 1.8502E-04
# True
# Itr = 2, residual norm = 5.4052E-06
# True
# Itr = 3, residual norm = 1.5886E-07
# True
# Itr = 4, residual norm = 4.6988E-09
# True
# Itr = 5, residual norm = 1.3846E-10
# True
# Itr = 6, residual norm = 4.0948E-12
# Time = 1.9626666666667105, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0690E-03
# True
# Itr = 1, residual norm = 1.8593E-04
# True
# Itr = 2, residual norm = 5.4882E-06
# True
# Itr = 3, residual norm = 1.6290E-07
# True
# Itr = 4, residual norm = 4.8703E-09
# True
# Itr = 5, residual norm = 1.4495E-10
# True
# Itr = 6, residual norm = 4.3329E-12
# Time = 1.964000000000044, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0530E-03
# True
# Itr = 1, residual norm = 1.8674E-04
# True
# Itr = 2, residual norm = 5.5698E-06
# True
# Itr = 3, residual norm = 1.6697E-07
# True
# Itr = 4, residual norm = 5.0466E-09
# True
# Itr = 5, residual norm = 1.5170E-10
# True
# Itr = 6, residual norm = 4.5843E-12
# Time = 1.9653333333333773, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0353E-03
# True
# Itr = 1, residual norm = 1.8745E-04
# True
# Itr = 2, residual norm = 5.6494E-06
# True
# Itr = 3, residual norm = 1.7105E-07
# True
# Itr = 4, residual norm = 5.2264E-09
# True
# Itr = 5, residual norm = 1.5869E-10
# True
# Itr = 6, residual norm = 4.8478E-12
# Time = 1.9666666666667107, dt = 0.0013333333333333333
# Itr = 0, residual norm = 7.0159E-03
# True
# Itr = 1, residual norm = 1.8805E-04
# True
# Itr = 2, residual norm = 5.7263E-06
# True
# Itr = 3, residual norm = 1.7511E-07
# True
# Itr = 4, residual norm = 5.4086E-09
# True
# Itr = 5, residual norm = 1.6587E-10
# True
# Itr = 6, residual norm = 5.1223E-12
# Time = 1.9680000000000442, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9949E-03
# True
# Itr = 1, residual norm = 1.8853E-04
# True
# Itr = 2, residual norm = 5.7997E-06
# True
# Itr = 3, residual norm = 1.7911E-07
# True
# Itr = 4, residual norm = 5.5919E-09
# True
# Itr = 5, residual norm = 1.7320E-10
# True
# Itr = 6, residual norm = 5.4065E-12
# Time = 1.9693333333333776, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9725E-03
# True
# Itr = 1, residual norm = 1.8888E-04
# True
# Itr = 2, residual norm = 5.8692E-06
# True
# Itr = 3, residual norm = 1.8302E-07
# True
# Itr = 4, residual norm = 5.7752E-09
# True
# Itr = 5, residual norm = 1.8063E-10
# True
# Itr = 6, residual norm = 5.6989E-12
# Time = 1.970666666666711, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9487E-03
# True
# Itr = 1, residual norm = 1.8909E-04
# True
# Itr = 2, residual norm = 5.9342E-06
# True
# Itr = 3, residual norm = 1.8683E-07
# True
# Itr = 4, residual norm = 5.9574E-09
# True
# Itr = 5, residual norm = 1.8813E-10
# True
# Itr = 6, residual norm = 5.9980E-12
# Time = 1.9720000000000444, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9236E-03
# True
# Itr = 1, residual norm = 1.8917E-04
# True
# Itr = 2, residual norm = 5.9942E-06
# True
# Itr = 3, residual norm = 1.9050E-07
# True
# Itr = 4, residual norm = 6.1373E-09
# True
# Itr = 5, residual norm = 1.9565E-10
# True
# Itr = 6, residual norm = 6.3023E-12
# Time = 1.9733333333333778, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.8974E-03
# True
# Itr = 1, residual norm = 1.8911E-04
# True
# Itr = 2, residual norm = 6.0490E-06
# True
# Itr = 3, residual norm = 1.9401E-07
# True
# Itr = 4, residual norm = 6.3139E-09
# True
# Itr = 5, residual norm = 2.0316E-10
# True
# Itr = 6, residual norm = 6.6104E-12
# Time = 1.9746666666667112, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.8702E-03
# True
# Itr = 1, residual norm = 1.8891E-04
# True
# Itr = 2, residual norm = 6.0982E-06
# True
# Itr = 3, residual norm = 1.9736E-07
# True
# Itr = 4, residual norm = 6.4864E-09
# True
# Itr = 5, residual norm = 2.1060E-10
# True
# Itr = 6, residual norm = 6.9207E-12
# Time = 1.9760000000000446, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.8420E-03
# True
# Itr = 1, residual norm = 1.8857E-04
# True
# Itr = 2, residual norm = 6.1416E-06
# True
# Itr = 3, residual norm = 2.0051E-07
# True
# Itr = 4, residual norm = 6.6539E-09
# True
# Itr = 5, residual norm = 2.1796E-10
# True
# Itr = 6, residual norm = 7.2317E-12
# Time = 1.977333333333378, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.8131E-03
# True
# Itr = 1, residual norm = 1.8809E-04
# True
# Itr = 2, residual norm = 6.1791E-06
# True
# Itr = 3, residual norm = 2.0346E-07
# True
# Itr = 4, residual norm = 6.8158E-09
# True
# Itr = 5, residual norm = 2.2518E-10
# True
# Itr = 6, residual norm = 7.5423E-12
# Time = 1.9786666666667114, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.7834E-03
# True
# Itr = 1, residual norm = 1.8747E-04
# True
# Itr = 2, residual norm = 6.2106E-06
# True
# Itr = 3, residual norm = 2.0620E-07
# True
# Itr = 4, residual norm = 6.9713E-09
# True
# Itr = 5, residual norm = 2.3226E-10
# True
# Itr = 6, residual norm = 7.8511E-12
# Time = 1.9800000000000448, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.7531E-03
# True
# Itr = 1, residual norm = 1.8672E-04
# True
# Itr = 2, residual norm = 6.2359E-06
# True
# Itr = 3, residual norm = 2.0872E-07
# True
# Itr = 4, residual norm = 7.1201E-09
# True
# Itr = 5, residual norm = 2.3915E-10
# True
# Itr = 6, residual norm = 8.1571E-12
# Time = 1.9813333333333782, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.7223E-03
# True
# Itr = 1, residual norm = 1.8584E-04
# True
# Itr = 2, residual norm = 6.2553E-06
# True
# Itr = 3, residual norm = 2.1102E-07
# True
# Itr = 4, residual norm = 7.2617E-09
# True
# Itr = 5, residual norm = 2.4585E-10
# True
# Itr = 6, residual norm = 8.4593E-12
# Time = 1.9826666666667117, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.6912E-03
# True
# Itr = 1, residual norm = 1.8483E-04
# True
# Itr = 2, residual norm = 6.2686E-06
# True
# Itr = 3, residual norm = 2.1309E-07
# True
# Itr = 4, residual norm = 7.3959E-09
# True
# Itr = 5, residual norm = 2.5233E-10
# True
# Itr = 6, residual norm = 8.7568E-12
# Time = 1.984000000000045, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.6597E-03
# True
# Itr = 1, residual norm = 1.8370E-04
# True
# Itr = 2, residual norm = 6.2761E-06
# True
# Itr = 3, residual norm = 2.1494E-07
# True
# Itr = 4, residual norm = 7.5224E-09
# True
# Itr = 5, residual norm = 2.5858E-10
# True
# Itr = 6, residual norm = 9.0488E-12
# Time = 1.9853333333333785, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.6281E-03
# True
# Itr = 1, residual norm = 1.8246E-04
# True
# Itr = 2, residual norm = 6.2778E-06
# True
# Itr = 3, residual norm = 2.1657E-07
# True
# Itr = 4, residual norm = 7.6411E-09
# True
# Itr = 5, residual norm = 2.6459E-10
# True
# Itr = 6, residual norm = 9.3348E-12
# Time = 1.9866666666667119, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.5964E-03
# True
# Itr = 1, residual norm = 1.8110E-04
# True
# Itr = 2, residual norm = 6.2740E-06
# True
# Itr = 3, residual norm = 2.1797E-07
# True
# Itr = 4, residual norm = 7.7520E-09
# True
# Itr = 5, residual norm = 2.7035E-10
# True
# Itr = 6, residual norm = 9.6144E-12
# Time = 1.9880000000000453, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.5647E-03
# True
# Itr = 1, residual norm = 1.7965E-04
# True
# Itr = 2, residual norm = 6.2649E-06
# True
# Itr = 3, residual norm = 2.1916E-07
# True
# Itr = 4, residual norm = 7.8550E-09
# True
# Itr = 5, residual norm = 2.7586E-10
# True
# Itr = 6, residual norm = 9.8869E-12
# Time = 1.9893333333333787, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.5332E-03
# True
# Itr = 1, residual norm = 1.7810E-04
# True
# Itr = 2, residual norm = 6.2506E-06
# True
# Itr = 3, residual norm = 2.2015E-07
# True
# Itr = 4, residual norm = 7.9503E-09
# True
# Itr = 5, residual norm = 2.8112E-10
# True
# Itr = 6, residual norm = 1.0152E-11
# Time = 1.990666666666712, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.5018E-03
# True
# Itr = 1, residual norm = 1.7647E-04
# True
# Itr = 2, residual norm = 6.2315E-06
# True
# Itr = 3, residual norm = 2.2093E-07
# True
# Itr = 4, residual norm = 8.0379E-09
# True
# Itr = 5, residual norm = 2.8611E-10
# True
# Itr = 6, residual norm = 1.0410E-11
# Time = 1.9920000000000455, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.4707E-03
# True
# Itr = 1, residual norm = 1.7475E-04
# True
# Itr = 2, residual norm = 6.2077E-06
# True
# Itr = 3, residual norm = 2.2151E-07
# True
# Itr = 4, residual norm = 8.1179E-09
# True
# Itr = 5, residual norm = 2.9085E-10
# True
# Itr = 6, residual norm = 1.0660E-11
# Time = 1.993333333333379, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.4400E-03
# True
# Itr = 1, residual norm = 1.7296E-04
# True
# Itr = 2, residual norm = 6.1797E-06
# True
# Itr = 3, residual norm = 2.2191E-07
# True
# Itr = 4, residual norm = 8.1904E-09
# True
# Itr = 5, residual norm = 2.9533E-10
# True
# Itr = 6, residual norm = 1.0902E-11
# Time = 1.9946666666667123, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.4098E-03
# True
# Itr = 1, residual norm = 1.7112E-04
# True
# Itr = 2, residual norm = 6.1475E-06
# True
# Itr = 3, residual norm = 2.2213E-07
# True
# Itr = 4, residual norm = 8.2557E-09
# True
# Itr = 5, residual norm = 2.9956E-10
# True
# Itr = 6, residual norm = 1.1135E-11
# Time = 1.9960000000000457, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.3802E-03
# True
# Itr = 1, residual norm = 1.6922E-04
# True
# Itr = 2, residual norm = 6.1117E-06
# True
# Itr = 3, residual norm = 2.2218E-07
# True
# Itr = 4, residual norm = 8.3139E-09
# True
# Itr = 5, residual norm = 3.0353E-10
# True
# Itr = 6, residual norm = 1.1360E-11
# Time = 1.9973333333333791, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.3511E-03
# True
# Itr = 1, residual norm = 1.6727E-04
# True
# Itr = 2, residual norm = 6.0724E-06
# True
# Itr = 3, residual norm = 2.2208E-07
# True
# Itr = 4, residual norm = 8.3651E-09
# True
# Itr = 5, residual norm = 3.0724E-10
# True
# Itr = 6, residual norm = 1.1576E-11
# Time = 1.9986666666667126, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.3228E-03
# True
# Itr = 1, residual norm = 1.6530E-04
# True
# Itr = 2, residual norm = 6.0300E-06
# True
# Itr = 3, residual norm = 2.2182E-07
# True
# Itr = 4, residual norm = 8.4096E-09
# True
# Itr = 5, residual norm = 3.1071E-10
# True
# Itr = 6, residual norm = 1.1783E-11
# Time = 2.0000000000000457, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.2952E-03
# True
# Itr = 1, residual norm = 1.6330E-04
# True
# Itr = 2, residual norm = 5.9849E-06
# True
# Itr = 3, residual norm = 2.2143E-07
# True
# Itr = 4, residual norm = 8.4476E-09
# True
# Itr = 5, residual norm = 3.1392E-10
# True
# Itr = 6, residual norm = 1.1980E-11

# %%
t
# Out:
# 2.0000000000000457

# %%
approximate = (nrbs.decode(sol[t]) + x_ref).detach().cpu().numpy()
# plot
ny = 60
nx = 60
x = np.load('paper_x.npy')
y = np.load('paper_y.npy')


fig_u = plt.figure()
ax_u = fig_u.gca()
p_u=ax_u.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), (approximate).reshape(ny,nx))
cb_u=fig_u.colorbar(p_u,ax=ax_u)
ax_u.set_xlabel('$x$')
ax_u.set_ylabel('$y$')
plt.title('$u$ ($t = {:}$)'.format(t))
plt.show()

# %%
ref_sol = X_test[-1]
approximate = (nrbs.decode(sol[t]) + x_ref)
torch.sqrt(torch.sum(approximate - ref_sol)**2) / torch.sqrt(torch.sum(ref_sol**2))
# Out:
# tensor(0.0200, device='cuda:0', grad_fn=<DivBackward0>)

# %%
# for t, x_red in sol.items():
#     approximate = (nrbs.decode(x_red) + x_ref).detach().cpu().numpy()
#     # plot
#     ny = 60
#     nx = 60
#     x = np.load('paper_x.npy')
#     y = np.load('paper_y.npy')


#     fig_u = plt.figure()
#     ax_u = fig_u.gca()
#     p_u=ax_u.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), (approximate).reshape(ny,nx))
#     cb_u=fig_u.colorbar(p_u,ax=ax_u)
#     ax_u.set_xlabel('$x$')
#     ax_u.set_ylabel('$y$')
#     plt.title('$u$ ($t = {:}$)'.format(t))
#     plt.show()
