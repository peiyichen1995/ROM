# %%
import jax
from jax import numpy as jnp
from matplotlib import pyplot as plt
from jax.config import config

config.update("jax_enable_x64", True)

# %%
def grad_hat(x_hat, basis, nx, ny):
    x_tilde = jnp.matmul(basis, x_hat)
    x_tilde_grad = jnp.gradient(x_tilde.reshape(nx, ny))
    return jnp.stack(
        (
            jnp.matmul(x_tilde_grad[0].flatten(), basis),
            jnp.matmul(x_tilde_grad[1].flatten(), basis),
        )
    ).T

# %%
data = jnp.load("mu_0.9.npy")

S, N = data.shape
end_time = 2
dt = 2 / (S - 1)
nx = 60
ny = 60

assert nx * ny == N

S -= 1
data_dot = (data[1:] - data[:-1]) / dt
data = data[1:]

X_dot = data_dot
X = data
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# number of basis
n = 20

D, V = jnp.linalg.eigh(jnp.matmul(X.T, X))
idx = jnp.argsort(D)[::-1]
D = D[idx]
V = V[:, idx]
basis = V[:, :n]

# %%
X_hat = jnp.matmul(X, basis)
X_dot_hat = jnp.matmul(X_dot, basis)

# %%
D = jnp.zeros((S, n + n * n + 2 * n * n))
for i in range(S):
    D = D.at[i, 0:n].set(X_hat[i])
    D = D.at[i, n : n + n * n].set(jnp.outer(X_hat[i], X_hat[i]).flatten())
    D = D.at[i, n + n * n :].set(
        jnp.outer(X_hat[i], grad_hat(X_hat[i], basis, nx, ny)).flatten()
    )

# %%
res = jnp.linalg.lstsq(D, X_dot_hat, rcond=1e-11)
AHG = res[0]
A = AHG[0:n, :].T
H = AHG[n : n + n * n, :].T
G = AHG[n + n * n :, :].T

# %%
def nr_solve(f, df, x, atol=1e-10, rtol=1e-8, max_itr=50, args=None):
    r = f(x, *args)
    nr = jnp.linalg.norm(r)
    nr0 = nr
    print("Itr = {:}, residual norm = {:.4E}".format(0, nr))
    if (nr < atol):
        return x
    for i in range(max_itr):
        p = jnp.linalg.solve(df(x, *args), r)
        x -= p
        r = f(x, *args)
        nr = jnp.linalg.norm(r)
        print("Itr = {:}, residual norm = {:.4E}".format(i + 1, nr))
        if (nr < atol or nr < rtol * nr0):
            return x
        
    raise Exception("solve failed")

# %%
def f(x, t):
    x_dot = 0
    x_dot += jnp.matmul(A, x)
    x_dot += jnp.matmul(H, jnp.outer(x, x).flatten())
    grad_x = grad_hat(x, basis, nx, ny)
    x_dot += jnp.matmul(G, jnp.outer(x, grad_x).flatten())
    return x_dot

df = jax.jit(jax.jacrev(f))

def residual(x, t, x_old, dt):
    return x - x_old - dt * f(x, t)


jacobian = jax.jit(jax.jacrev(residual))

# %%
x_hat = X_hat[0]
t = 0
sol = {t: x_hat}
dt = 2 / S
dt_min = dt / 100
while t < 2:
    print("Time = {:}, dt = {:}".format(t + dt, dt))
    try:
        x_hat = nr_solve(residual, jacobian, x_hat, args=(t, x_hat, dt), max_itr=20)
    except:
        dt = dt / 2
        if dt < dt_min:
            raise Exception("dt is too small")
        continue
    t = t + dt
    sol[t] = x_hat
# Out:
# Time = 0.0013333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.7980E-02
# Itr = 1, residual norm = 1.1782E-02
# Itr = 2, residual norm = 1.3120E-06
# Itr = 3, residual norm = 3.2176E-13
# Time = 0.0026666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8076E-02
# Itr = 1, residual norm = 1.1922E-02
# Itr = 2, residual norm = 1.3268E-06
# Itr = 3, residual norm = 3.5371E-13
# Time = 0.004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8165E-02
# Itr = 1, residual norm = 1.2062E-02
# Itr = 2, residual norm = 1.3416E-06
# Itr = 3, residual norm = 2.9907E-13
# Time = 0.005333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8246E-02
# Itr = 1, residual norm = 1.2201E-02
# Itr = 2, residual norm = 1.3564E-06
# Itr = 3, residual norm = 3.6145E-13
# Time = 0.006666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8319E-02
# Itr = 1, residual norm = 1.2340E-02
# Itr = 2, residual norm = 1.3712E-06
# Itr = 3, residual norm = 2.9770E-13
# Time = 0.008, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8385E-02
# Itr = 1, residual norm = 1.2477E-02
# Itr = 2, residual norm = 1.3859E-06
# Itr = 3, residual norm = 2.6320E-13
# Time = 0.009333333333333334, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8444E-02
# Itr = 1, residual norm = 1.2613E-02
# Itr = 2, residual norm = 1.4006E-06
# Itr = 3, residual norm = 1.6258E-13
# Time = 0.010666666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8496E-02
# Itr = 1, residual norm = 1.2749E-02
# Itr = 2, residual norm = 1.4150E-06
# Itr = 3, residual norm = 3.2740E-13
# Time = 0.012000000000000002, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8540E-02
# Itr = 1, residual norm = 1.2883E-02
# Itr = 2, residual norm = 1.4294E-06
# Itr = 3, residual norm = 3.1618E-13
# Time = 0.013333333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8578E-02
# Itr = 1, residual norm = 1.3017E-02
# Itr = 2, residual norm = 1.4432E-06
# Itr = 3, residual norm = 1.6235E-13
# Time = 0.01466666666666667, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8609E-02
# Itr = 1, residual norm = 1.3148E-02
# Itr = 2, residual norm = 1.4574E-06
# Itr = 3, residual norm = 2.6278E-13
# Time = 0.016000000000000004, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8635E-02
# Itr = 1, residual norm = 1.3281E-02
# Itr = 2, residual norm = 1.4700E-06
# Itr = 3, residual norm = 3.0213E-13
# Time = 0.017333333333333336, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8649E-02
# Itr = 1, residual norm = 1.3406E-02
# Itr = 2, residual norm = 1.4853E-06
# Itr = 3, residual norm = 1.9003E-13
# Time = 0.018666666666666668, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8670E-02
# Itr = 1, residual norm = 1.3545E-02
# Itr = 2, residual norm = 1.4929E-06
# Itr = 3, residual norm = 3.3133E-13
# Time = 0.02, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8654E-02
# Itr = 1, residual norm = 1.3646E-02
# Itr = 2, residual norm = 1.5173E-06
# Itr = 3, residual norm = 2.7235E-13
# Time = 0.021333333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8706E-02
# Itr = 1, residual norm = 1.3833E-02
# Itr = 2, residual norm = 1.5010E-06
# Itr = 3, residual norm = 3.2634E-13
# Time = 0.022666666666666665, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8581E-02
# Itr = 1, residual norm = 1.3810E-02
# Itr = 2, residual norm = 1.5805E-06
# Itr = 3, residual norm = 2.3065E-13
# Time = 0.023999999999999997, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8851E-02
# Itr = 1, residual norm = 1.4307E-02
# Itr = 2, residual norm = 1.4444E-06
# Itr = 3, residual norm = 3.0965E-13
# Time = 0.02533333333333333, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.8231E-02
# Itr = 1, residual norm = 1.3639E-02
# Itr = 2, residual norm = 1.8761E-06
# Itr = 3, residual norm = 3.0853E-13
# Time = 0.02666666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.9839E-02
# Itr = 1, residual norm = 1.6327E-02
# Itr = 2, residual norm = 1.2969E-06
# Itr = 3, residual norm = 4.0989E-13
# Time = 0.027999999999999994, dt = 0.0013333333333333333
# Itr = 0, residual norm = 5.7504E-02
# Itr = 1, residual norm = 1.3756E-02
# Itr = 2, residual norm = 6.4589E-06
# Itr = 3, residual norm = 2.8877E-13
# Time = 0.029333333333333326, dt = 0.0013333333333333333
# Itr = 0, residual norm = 6.9742E-02
# Itr = 1, residual norm = 4.3322E-02
# Itr = 2, residual norm = 2.8429E-05
# Itr = 3, residual norm = 2.0447E-11
# Time = 0.030666666666666658, dt = 0.0013333333333333333
# Itr = 0, residual norm = 8.1620E-02
# Itr = 1, residual norm = 1.2591E-01
# Itr = 2, residual norm = 1.0837E-03
# Itr = 3, residual norm = 2.7944E-09
# Itr = 4, residual norm = 2.0595E-13
# Time = 0.031999999999999994, dt = 0.0013333333333333333
# Itr = 0, residual norm = 1.7761E-01
# Itr = 1, residual norm = 5.9859E-01
# Itr = 2, residual norm = 2.7500E-02
# Itr = 3, residual norm = 8.1741E-07
# Itr = 4, residual norm = 1.4147E-13
# Time = 0.033333333333333326, dt = 0.0013333333333333333
# Itr = 0, residual norm = 3.9261E-01
# Itr = 1, residual norm = 7.0167E+00
# Itr = 2, residual norm = 1.0414E+00
# Itr = 3, residual norm = 8.1893E-04
# Itr = 4, residual norm = 1.3729E-08
# Itr = 5, residual norm = 2.3048E-13
# Time = 0.03466666666666666, dt = 0.0013333333333333333
# Itr = 0, residual norm = 8.4463E-01
# Itr = 1, residual norm = 5.7869E+00
# Itr = 2, residual norm = 2.8631E+01
# Itr = 3, residual norm = 5.2811E-01
# Itr = 4, residual norm = 3.9181E-01
# Itr = 5, residual norm = 4.9145E-05
# Itr = 6, residual norm = 4.0650E-10
# Time = 0.03599999999999999, dt = 0.0013333333333333333
# Itr = 0, residual norm = 2.7613E+00
# Itr = 1, residual norm = 2.3503E+03
# Itr = 2, residual norm = 5.6033E+02
# Itr = 3, residual norm = 4.8315E+02
# Itr = 4, residual norm = 6.2787E+02
# Itr = 5, residual norm = 5.5088E+02
# Itr = 6, residual norm = 1.7746E+02
# Itr = 7, residual norm = 3.7034E+03
# Itr = 8, residual norm = 6.9774E+02
# Itr = 9, residual norm = 2.7793E+02
# Itr = 10, residual norm = 4.2376E+03
# Itr = 11, residual norm = 9.9946E+02
# Itr = 12, residual norm = 8.0137E+02
# Itr = 13, residual norm = 1.4124E+02
# Itr = 14, residual norm = 3.1438E+03
# Itr = 15, residual norm = 7.7025E+02
# Itr = 16, residual norm = 1.9213E+02
# Itr = 17, residual norm = 1.1779E+04
# Itr = 18, residual norm = 2.9020E+03
# Itr = 19, residual norm = 3.7770E+02
# Itr = 20, residual norm = 5.3470E+02
# Time = 0.03533333333333333, dt = 0.0006666666666666666
# Itr = 0, residual norm = 1.3806E+00
# Itr = 1, residual norm = 4.7437E+01
# Itr = 2, residual norm = 2.7753E+00
# Itr = 3, residual norm = 3.1643E-01
# Itr = 4, residual norm = 3.6022E-04
# Itr = 5, residual norm = 1.1580E-09
# Time = 0.036, dt = 0.0006666666666666666
# Itr = 0, residual norm = 2.7360E+00
# Itr = 1, residual norm = 7.2215E+01
# Itr = 2, residual norm = 1.0040E+02
# Itr = 3, residual norm = 4.6591E+01
# Itr = 4, residual norm = 4.8596E+02
# Itr = 5, residual norm = 1.2741E+02
# Itr = 6, residual norm = 3.0509E+01
# Itr = 7, residual norm = 2.4749E+01
# Itr = 8, residual norm = 1.8519E+01
# Itr = 9, residual norm = 3.8346E+00
# Itr = 10, residual norm = 4.4029E-02
# Itr = 11, residual norm = 2.2047E-03
# Itr = 12, residual norm = 4.4436E-08
# Itr = 13, residual norm = 1.4730E-13
# Time = 0.03666666666666667, dt = 0.0006666666666666666
# Itr = 0, residual norm = 3.2732E+00
# Itr = 1, residual norm = 2.6179E+01
# Itr = 2, residual norm = 7.8806E+00
# Itr = 3, residual norm = 1.3726E+02
# Itr = 4, residual norm = 4.2171E+01
# Itr = 5, residual norm = 5.5665E+02
# Itr = 6, residual norm = 2.1999E+02
# Itr = 7, residual norm = 9.5331E+01
# Itr = 8, residual norm = 2.9845E+01
# Itr = 9, residual norm = 3.3656E+02
# Itr = 10, residual norm = 1.7841E+02
# Itr = 11, residual norm = 1.0223E+04
# Itr = 12, residual norm = 2.5760E+03
# Itr = 13, residual norm = 6.5171E+02
# Itr = 14, residual norm = 1.9251E+02
# Itr = 15, residual norm = 1.1862E+02
# Itr = 16, residual norm = 1.8787E+03
# Itr = 17, residual norm = 6.3051E+02
# Itr = 18, residual norm = 2.6994E+02
# Itr = 19, residual norm = 2.9980E+03
# Itr = 20, residual norm = 8.0715E+02
# Time = 0.03633333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.6366E+00
# Itr = 1, residual norm = 1.9739E+01
# Itr = 2, residual norm = 1.2761E+01
# Itr = 3, residual norm = 5.4212E+03
# Itr = 4, residual norm = 1.3579E+03
# Itr = 5, residual norm = 3.4398E+02
# Itr = 6, residual norm = 9.3445E+01
# Itr = 7, residual norm = 3.2580E+01
# Itr = 8, residual norm = 1.7926E+01
# Itr = 9, residual norm = 3.5449E+03
# Itr = 10, residual norm = 8.8756E+02
# Itr = 11, residual norm = 3.9844E+02
# Itr = 12, residual norm = 1.3344E+02
# Itr = 13, residual norm = 1.5574E+02
# Itr = 14, residual norm = 1.2638E+02
# Itr = 15, residual norm = 4.6368E+02
# Itr = 16, residual norm = 1.1230E+04
# Itr = 17, residual norm = 2.6108E+03
# Itr = 18, residual norm = 9.8457E+02
# Itr = 19, residual norm = 2.5418E+03
# Itr = 20, residual norm = 5.8231E+02
# Time = 0.036166666666666666, dt = 0.00016666666666666666
# Itr = 0, residual norm = 8.1831E-01
# Itr = 1, residual norm = 2.4725E+00
# Itr = 2, residual norm = 1.8234E-01
# Itr = 3, residual norm = 3.1908E-03
# Itr = 4, residual norm = 5.1629E-07
# Itr = 5, residual norm = 5.5009E-14
# Time = 0.036333333333333336, dt = 0.00016666666666666666
# Itr = 0, residual norm = 1.3855E+00
# Itr = 1, residual norm = 2.9509E+00
# Itr = 2, residual norm = 2.3385E+01
# Itr = 3, residual norm = 4.5420E+00
# Itr = 4, residual norm = 2.3985E+00
# Itr = 5, residual norm = 6.4467E-02
# Itr = 6, residual norm = 2.1306E-04
# Itr = 7, residual norm = 2.3484E-09
# Time = 0.036500000000000005, dt = 0.00016666666666666666
# Itr = 0, residual norm = 3.3886E+00
# Itr = 1, residual norm = 1.2372E+02
# Itr = 2, residual norm = 2.4859E+01
# Itr = 3, residual norm = 7.3598E+00
# Itr = 4, residual norm = 5.5812E-01
# Itr = 5, residual norm = 1.9658E-03
# Itr = 6, residual norm = 1.7660E-08
# Time = 0.036666666666666674, dt = 0.00016666666666666666
# Itr = 0, residual norm = 6.0250E+00
# Itr = 1, residual norm = 2.7077E+01
# Itr = 2, residual norm = 3.7362E+02
# Itr = 3, residual norm = 1.0035E+02
# Itr = 4, residual norm = 1.4443E+02
# Itr = 5, residual norm = 3.5249E+01
# Itr = 6, residual norm = 3.3558E+01
# Itr = 7, residual norm = 1.0310E+02
# Itr = 8, residual norm = 8.9040E+01
# Itr = 9, residual norm = 3.8457E+01
# Itr = 10, residual norm = 4.2517E+01
# Itr = 11, residual norm = 5.9220E+01
# Itr = 12, residual norm = 2.8447E+01
# Itr = 13, residual norm = 2.0951E+01
# Itr = 14, residual norm = 1.0953E+01
# Itr = 15, residual norm = 2.8753E+02
# Itr = 16, residual norm = 9.0955E+03
# Itr = 17, residual norm = 2.7831E+03
# Itr = 18, residual norm = 7.7142E+02
# Itr = 19, residual norm = 5.1350E+03
# Itr = 20, residual norm = 1.4745E+03
# Time = 0.036583333333333336, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 3.0125E+00
# Itr = 1, residual norm = 2.7330E+00
# Itr = 2, residual norm = 8.7670E-01
# Itr = 3, residual norm = 1.5167E+00
# Itr = 4, residual norm = 1.6524E+00
# Itr = 5, residual norm = 6.3228E-01
# Itr = 6, residual norm = 1.1984E+01
# Itr = 7, residual norm = 3.1667E+00
# Itr = 8, residual norm = 9.9786E-01
# Itr = 9, residual norm = 7.2484E-01
# Itr = 10, residual norm = 1.8690E+00
# Itr = 11, residual norm = 7.1914E-01
# Itr = 12, residual norm = 2.0044E+00
# Itr = 13, residual norm = 7.4414E-01
# Itr = 14, residual norm = 1.5466E+00
# Itr = 15, residual norm = 6.7042E-01
# Itr = 16, residual norm = 7.1161E+00
# Itr = 17, residual norm = 1.9593E+00
# Itr = 18, residual norm = 7.3559E-01
# Itr = 19, residual norm = 1.6708E+00
# Itr = 20, residual norm = 6.8679E-01
# Time = 0.036541666666666674, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 1.5063E+00
# Itr = 1, residual norm = 3.8883E+00
# Itr = 2, residual norm = 2.1535E+01
# Itr = 3, residual norm = 3.6244E+00
# Itr = 4, residual norm = 8.5596E-01
# Itr = 5, residual norm = 3.7952E-02
# Itr = 6, residual norm = 4.5289E-04
# Itr = 7, residual norm = 9.3747E-08
# Itr = 8, residual norm = 2.4638E-14
# Time = 0.03658333333333334, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 2.2026E+00
# Itr = 1, residual norm = 6.6847E-01
# Itr = 2, residual norm = 2.4808E-01
# Itr = 3, residual norm = 7.1808E-03
# Itr = 4, residual norm = 3.6451E-06
# Itr = 5, residual norm = 3.9388E-12
# Time = 0.03662500000000001, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 2.8556E+00
# Itr = 1, residual norm = 1.2689E+00
# Itr = 2, residual norm = 4.1323E-01
# Itr = 3, residual norm = 1.1994E-02
# Itr = 4, residual norm = 3.9363E-05
# Itr = 5, residual norm = 2.8701E-10
# Time = 0.03666666666666668, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 3.4296E+00
# Itr = 1, residual norm = 3.1437E+00
# Itr = 2, residual norm = 2.9500E-01
# Itr = 3, residual norm = 2.4379E-02
# Itr = 4, residual norm = 9.7079E-05
# Itr = 5, residual norm = 6.4414E-10
# Time = 0.03670833333333335, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 4.2038E+00
# Itr = 1, residual norm = 6.9094E+00
# Itr = 2, residual norm = 5.8487E+00
# Itr = 3, residual norm = 1.0600E+00
# Itr = 4, residual norm = 1.7877E-02
# Itr = 5, residual norm = 1.0142E-05
# Itr = 6, residual norm = 3.0764E-12
# Time = 0.03675000000000002, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 5.7384E+00
# Itr = 1, residual norm = 2.6558E+01
# Itr = 2, residual norm = 3.2348E+02
# Itr = 3, residual norm = 8.4012E+01
# Itr = 4, residual norm = 1.1026E+02
# Itr = 5, residual norm = 1.0156E+02
# Itr = 6, residual norm = 1.6096E+02
# Itr = 7, residual norm = 3.5965E+03
# Itr = 8, residual norm = 8.4766E+02
# Itr = 9, residual norm = 1.5107E+03
# Itr = 10, residual norm = 3.6917E+02
# Itr = 11, residual norm = 9.2325E+03
# Itr = 12, residual norm = 2.0951E+03
# Itr = 13, residual norm = 5.5010E+03
# Itr = 14, residual norm = 1.8246E+03
# Itr = 15, residual norm = 8.6013E+04
# Itr = 16, residual norm = 2.2082E+04
# Itr = 17, residual norm = 5.9698E+05
# Itr = 18, residual norm = 1.3794E+05
# Itr = 19, residual norm = 3.0587E+04
# Itr = 20, residual norm = 1.5768E+04
# Time = 0.03672916666666668, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 2.8692E+00
# Itr = 1, residual norm = 9.1636E-01
# Itr = 2, residual norm = 1.0038E-01
# Itr = 3, residual norm = 3.2283E-05
# Itr = 4, residual norm = 1.3867E-11
# Time = 0.03675000000000001, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 3.9793E+00
# Itr = 1, residual norm = 5.1293E+00
# Itr = 2, residual norm = 2.1675E+01
# Itr = 3, residual norm = 4.5478E+00
# Itr = 4, residual norm = 3.3483E+00
# Itr = 5, residual norm = 8.7331E-02
# Itr = 6, residual norm = 4.2568E-04
# Itr = 7, residual norm = 9.5954E-10
# Time = 0.03677083333333334, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 1.2991E+01
# Itr = 1, residual norm = 1.2252E+03
# Itr = 2, residual norm = 2.9569E+02
# Itr = 3, residual norm = 1.9779E+02
# Itr = 4, residual norm = 1.7868E+03
# Itr = 5, residual norm = 1.6001E+03
# Itr = 6, residual norm = 8.2017E+02
# Itr = 7, residual norm = 2.1261E+02
# Itr = 8, residual norm = 7.3532E+02
# Itr = 9, residual norm = 1.1239E+03
# Itr = 10, residual norm = 4.2869E+03
# Itr = 11, residual norm = 2.5697E+03
# Itr = 12, residual norm = 4.9369E+05
# Itr = 13, residual norm = 1.2206E+05
# Itr = 14, residual norm = 2.4467E+04
# Itr = 15, residual norm = 3.8298E+03
# Itr = 16, residual norm = 1.7836E+03
# Itr = 17, residual norm = 4.4789E+03
# Itr = 18, residual norm = 1.2916E+07
# Itr = 19, residual norm = 3.2282E+06
# Itr = 20, residual norm = 8.0750E+05
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 9
#       8 try:
# ----> 9     x_hat = nr_solve(residual, jacobian, x_hat, args=(t, x_hat, dt), max_itr=20)
#      10 except:
#
# Cell In[9], line 17, in nr_solve(f, df, x, atol, rtol, max_itr, args)
#      15         return x
# ---> 17 raise Exception("solve failed")
#
# Exception: solve failed
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 13
#      11     dt = dt / 2
#      12     if dt < dt_min:
# ---> 13         raise Exception("dt is too small")
#      14     continue
#      15 t = t + dt
#
# Exception: dt is too small

# %%
t
# Out:
# 0.03675000000000001
