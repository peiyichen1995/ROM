# %%
import jax
from jax import numpy as jnp
from matplotlib import pyplot as plt
from jax.config import config

config.update("jax_enable_x64", True)

# %%
def grad_hat(x_hat, basis, nx, ny):
    x_tilde = jnp.matmul(basis, x_hat)
    x_tilde_grad = jnp.gradient(x_tilde.reshape(nx, ny))
    return jnp.stack(
        (
            jnp.matmul(x_tilde_grad[0].flatten(), basis),
            jnp.matmul(x_tilde_grad[1].flatten(), basis),
        )
    ).T

# %%
data1 = jnp.load("mu_0.9.npy")
data2 = jnp.load("mu_0.95.npy")
data3 = jnp.load("mu_1.05.npy")
data4 = jnp.load("mu_1.1.npy")

x_ref = jnp.mean(jnp.concatenate([data1, data2, data3, data4], axis=0), axis=0)

S, N = data1.shape
end_time = 2
dt = 2 / (S - 1)
nx = 60
ny = 60

assert nx * ny == N

data1_dot = (data1[1:] - data1[:-1]) / dt
data1 = data1[1:]

data2_dot = (data2[1:] - data2[:-1]) / dt
data2 = data2[1:]

data3_dot = (data3[1:] - data3[:-1]) / dt
data3 = data3[1:]

data4_dot = (data4[1:] - data4[:-1]) / dt
data4 = data4[1:]

X = jnp.concatenate([data1, data2, data3, data4], axis=0) - x_ref
X_dot = jnp.concatenate([data1_dot, data2_dot, data3_dot, data4_dot], axis=0)

S, N = X.shape

X_test = jnp.load("mu_1.0.npy")
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# number of basis
n = 20

D, V = jnp.linalg.eigh(jnp.matmul(X.T, X))
idx = jnp.argsort(D)[::-1]
D = D[idx]
V = V[:, idx]
basis = V[:, :n]

# %%
X_hat = jnp.matmul(X, basis)
X_dot_hat = jnp.matmul(X_dot, basis)

X_test_hat = jnp.matmul(X_test - x_ref, basis)

# %%
D = jnp.zeros((S, n + n * n + 2 * n * n))
for i in range(S):
    D = D.at[i, 0:n].set(X_hat[i])
    D = D.at[i, n : n + n * n].set(jnp.outer(X_hat[i], X_hat[i]).flatten())
    D = D.at[i, n + n * n :].set(
        jnp.outer(X_hat[i], grad_hat(X_hat[i], basis, nx, ny)).flatten()
    )

# %%
res = jnp.linalg.lstsq(D, X_dot_hat, rcond=1e-11)
AHG = res[0]
A = AHG[0:n, :].T
H = AHG[n : n + n * n, :].T
G = AHG[n + n * n :, :].T

# %%
def nr_solve(f, df, x, atol=1e-10, rtol=1e-8, max_itr=50, args=None):
    r = f(x, *args)
    nr = jnp.linalg.norm(r)
    nr0 = nr
    print("Itr = {:}, residual norm = {:.4E}".format(0, nr))
    if (nr < atol):
        return x
    for i in range(max_itr):
        p = jnp.linalg.solve(df(x, *args), r)
        x -= p
        r = f(x, *args)
        nr = jnp.linalg.norm(r)
        print("Itr = {:}, residual norm = {:.4E}".format(i + 1, nr))
        if (nr < atol or nr < rtol * nr0):
            return x
        
    raise Exception("solve failed")

# %%
def f(x, t):
    x_dot = 0
    x_dot += jnp.matmul(A, x)
    x_dot += jnp.matmul(H, jnp.outer(x, x).flatten())
    grad_x = grad_hat(x, basis, nx, ny)
    x_dot += jnp.matmul(G, jnp.outer(x, grad_x).flatten())
    return x_dot

df = jax.jit(jax.jacrev(f))

def residual(x, t, x_old, dt):
    return x - x_old - dt * f(x, t)


jacobian = jax.jit(jax.jacrev(residual))

# %%
x_hat = X_test_hat[0]
t = 0
sol = {t: x_hat}
dt = 2 / S
dt_min = dt / 100
while t < 2:
    print("Time = {:}, dt = {:}".format(t + dt, dt))
    try:
        x_hat = nr_solve(residual, jacobian, x_hat, args=(t, x_hat, dt), max_itr=20)
    except:
        dt = dt / 2
        if dt < dt_min:
            raise Exception("dt is too small")
        continue
    t = t + dt
    sol[t] = x_hat
# Out:
# Time = 0.0003333333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7807E-02
# Itr = 1, residual norm = 1.7683E-06
# Itr = 2, residual norm = 9.5176E-13
# Time = 0.0006666666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7817E-02
# Itr = 1, residual norm = 1.7587E-06
# Itr = 2, residual norm = 8.7690E-13
# Time = 0.001, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7827E-02
# Itr = 1, residual norm = 1.7644E-06
# Itr = 2, residual norm = 1.0761E-12
# Time = 0.0013333333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7837E-02
# Itr = 1, residual norm = 1.7489E-06
# Itr = 2, residual norm = 9.5033E-13
# Time = 0.0016666666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7846E-02
# Itr = 1, residual norm = 1.7411E-06
# Itr = 2, residual norm = 1.1173E-12
# Time = 0.002, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7856E-02
# Itr = 1, residual norm = 1.7342E-06
# Itr = 2, residual norm = 9.7471E-13
# Time = 0.0023333333333333335, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7865E-02
# Itr = 1, residual norm = 1.7266E-06
# Itr = 2, residual norm = 1.0498E-12
# Time = 0.002666666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7874E-02
# Itr = 1, residual norm = 1.7198E-06
# Itr = 2, residual norm = 8.7039E-13
# Time = 0.0030000000000000005, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7883E-02
# Itr = 1, residual norm = 1.7133E-06
# Itr = 2, residual norm = 8.3874E-13
# Time = 0.003333333333333334, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7892E-02
# Itr = 1, residual norm = 1.7070E-06
# Itr = 2, residual norm = 9.3551E-13
# Time = 0.0036666666666666675, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7901E-02
# Itr = 1, residual norm = 1.7010E-06
# Itr = 2, residual norm = 8.0498E-13
# Time = 0.004000000000000001, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7910E-02
# Itr = 1, residual norm = 1.6951E-06
# Itr = 2, residual norm = 1.0187E-12
# Time = 0.004333333333333334, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7918E-02
# Itr = 1, residual norm = 1.6895E-06
# Itr = 2, residual norm = 1.1024E-12
# Time = 0.004666666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7926E-02
# Itr = 1, residual norm = 1.6839E-06
# Itr = 2, residual norm = 8.0927E-13
# Time = 0.005, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7934E-02
# Itr = 1, residual norm = 1.6785E-06
# Itr = 2, residual norm = 8.9194E-13
# Time = 0.005333333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7942E-02
# Itr = 1, residual norm = 1.6731E-06
# Itr = 2, residual norm = 9.2639E-13
# Time = 0.005666666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7950E-02
# Itr = 1, residual norm = 1.6678E-06
# Itr = 2, residual norm = 7.7425E-13
# Time = 0.005999999999999999, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7958E-02
# Itr = 1, residual norm = 1.6626E-06
# Itr = 2, residual norm = 8.5913E-13
# Time = 0.006333333333333332, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7966E-02
# Itr = 1, residual norm = 1.6574E-06
# Itr = 2, residual norm = 9.1236E-13
# Time = 0.006666666666666665, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7973E-02
# Itr = 1, residual norm = 1.6522E-06
# Itr = 2, residual norm = 6.6538E-13
# Time = 0.006999999999999998, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7980E-02
# Itr = 1, residual norm = 1.6470E-06
# Itr = 2, residual norm = 9.6054E-13
# Time = 0.0073333333333333315, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7987E-02
# Itr = 1, residual norm = 1.6419E-06
# Itr = 2, residual norm = 8.3809E-13
# Time = 0.0076666666666666645, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.7994E-02
# Itr = 1, residual norm = 1.6367E-06
# Itr = 2, residual norm = 8.3756E-13
# Time = 0.007999999999999998, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8001E-02
# Itr = 1, residual norm = 1.6316E-06
# Itr = 2, residual norm = 9.3101E-13
# Time = 0.008333333333333331, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8008E-02
# Itr = 1, residual norm = 1.6264E-06
# Itr = 2, residual norm = 8.2935E-13
# Time = 0.008666666666666665, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8014E-02
# Itr = 1, residual norm = 1.6213E-06
# Itr = 2, residual norm = 7.4843E-13
# Time = 0.008999999999999998, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8021E-02
# Itr = 1, residual norm = 1.6161E-06
# Itr = 2, residual norm = 7.2284E-13
# Time = 0.00933333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8027E-02
# Itr = 1, residual norm = 1.6109E-06
# Itr = 2, residual norm = 8.8368E-13
# Time = 0.009666666666666664, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8033E-02
# Itr = 1, residual norm = 1.6058E-06
# Itr = 2, residual norm = 8.7041E-13
# Time = 0.009999999999999997, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8039E-02
# Itr = 1, residual norm = 1.6006E-06
# Itr = 2, residual norm = 8.1783E-13
# Time = 0.01033333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8045E-02
# Itr = 1, residual norm = 1.5954E-06
# Itr = 2, residual norm = 6.9290E-13
# Time = 0.010666666666666663, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8051E-02
# Itr = 1, residual norm = 1.5902E-06
# Itr = 2, residual norm = 7.6225E-13
# Time = 0.010999999999999996, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8056E-02
# Itr = 1, residual norm = 1.5850E-06
# Itr = 2, residual norm = 8.5571E-13
# Time = 0.011333333333333329, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8062E-02
# Itr = 1, residual norm = 1.5798E-06
# Itr = 2, residual norm = 8.0409E-13
# Time = 0.011666666666666662, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8067E-02
# Itr = 1, residual norm = 1.5746E-06
# Itr = 2, residual norm = 7.9703E-13
# Time = 0.011999999999999995, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8072E-02
# Itr = 1, residual norm = 1.5694E-06
# Itr = 2, residual norm = 8.9313E-13
# Time = 0.012333333333333328, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8077E-02
# Itr = 1, residual norm = 1.5642E-06
# Itr = 2, residual norm = 6.6453E-13
# Time = 0.012666666666666661, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8082E-02
# Itr = 1, residual norm = 1.5591E-06
# Itr = 2, residual norm = 8.3385E-13
# Time = 0.012999999999999994, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8087E-02
# Itr = 1, residual norm = 1.5540E-06
# Itr = 2, residual norm = 7.9115E-13
# Time = 0.013333333333333327, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8092E-02
# Itr = 1, residual norm = 1.5490E-06
# Itr = 2, residual norm = 6.8510E-13
# Time = 0.01366666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8096E-02
# Itr = 1, residual norm = 1.5440E-06
# Itr = 2, residual norm = 6.7306E-13
# Time = 0.013999999999999993, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8101E-02
# Itr = 1, residual norm = 1.5390E-06
# Itr = 2, residual norm = 6.9196E-13
# Time = 0.014333333333333326, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8105E-02
# Itr = 1, residual norm = 1.5342E-06
# Itr = 2, residual norm = 8.0841E-13
# Time = 0.01466666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8109E-02
# Itr = 1, residual norm = 1.5294E-06
# Itr = 2, residual norm = 7.1211E-13
# Time = 0.014999999999999993, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8113E-02
# Itr = 1, residual norm = 1.5248E-06
# Itr = 2, residual norm = 7.5382E-13
# Time = 0.015333333333333326, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8118E-02
# Itr = 1, residual norm = 1.5202E-06
# Itr = 2, residual norm = 9.3995E-13
# Time = 0.01566666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8122E-02
# Itr = 1, residual norm = 1.5158E-06
# Itr = 2, residual norm = 7.8176E-13
# Time = 0.015999999999999993, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8125E-02
# Itr = 1, residual norm = 1.5116E-06
# Itr = 2, residual norm = 7.3374E-13
# Time = 0.016333333333333328, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8129E-02
# Itr = 1, residual norm = 1.5076E-06
# Itr = 2, residual norm = 5.7185E-13
# Time = 0.016666666666666663, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8133E-02
# Itr = 1, residual norm = 1.5037E-06
# Itr = 2, residual norm = 7.1350E-13
# Time = 0.016999999999999998, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8137E-02
# Itr = 1, residual norm = 1.5001E-06
# Itr = 2, residual norm = 8.1890E-13
# Time = 0.017333333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8140E-02
# Itr = 1, residual norm = 1.4968E-06
# Itr = 2, residual norm = 8.6693E-13
# Time = 0.017666666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8144E-02
# Itr = 1, residual norm = 1.4938E-06
# Itr = 2, residual norm = 8.4756E-13
# Time = 0.018000000000000002, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8147E-02
# Itr = 1, residual norm = 1.4911E-06
# Itr = 2, residual norm = 7.6797E-13
# Time = 0.018333333333333337, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8150E-02
# Itr = 1, residual norm = 1.4887E-06
# Itr = 2, residual norm = 7.2995E-13
# Time = 0.01866666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8154E-02
# Itr = 1, residual norm = 1.4868E-06
# Itr = 2, residual norm = 7.5310E-13
# Time = 0.019000000000000006, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8157E-02
# Itr = 1, residual norm = 1.4854E-06
# Itr = 2, residual norm = 8.9287E-13
# Time = 0.01933333333333334, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8160E-02
# Itr = 1, residual norm = 1.4845E-06
# Itr = 2, residual norm = 7.9146E-13
# Time = 0.019666666666666676, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8163E-02
# Itr = 1, residual norm = 1.4842E-06
# Itr = 2, residual norm = 7.0079E-13
# Time = 0.02000000000000001, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8166E-02
# Itr = 1, residual norm = 1.4846E-06
# Itr = 2, residual norm = 7.9559E-13
# Time = 0.020333333333333346, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8169E-02
# Itr = 1, residual norm = 1.4857E-06
# Itr = 2, residual norm = 8.3389E-13
# Time = 0.02066666666666668, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8172E-02
# Itr = 1, residual norm = 1.4876E-06
# Itr = 2, residual norm = 8.6796E-13
# Time = 0.021000000000000015, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8176E-02
# Itr = 1, residual norm = 1.4904E-06
# Itr = 2, residual norm = 9.1868E-13
# Time = 0.02133333333333335, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8179E-02
# Itr = 1, residual norm = 1.4942E-06
# Itr = 2, residual norm = 9.5834E-13
# Time = 0.021666666666666685, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8182E-02
# Itr = 1, residual norm = 1.4990E-06
# Itr = 2, residual norm = 8.3954E-13
# Time = 0.02200000000000002, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8185E-02
# Itr = 1, residual norm = 1.5052E-06
# Itr = 2, residual norm = 9.2677E-13
# Time = 0.022333333333333354, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8188E-02
# Itr = 1, residual norm = 1.5126E-06
# Itr = 2, residual norm = 1.0723E-12
# Time = 0.02266666666666669, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8191E-02
# Itr = 1, residual norm = 1.5216E-06
# Itr = 2, residual norm = 9.2790E-13
# Time = 0.023000000000000024, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8194E-02
# Itr = 1, residual norm = 1.5321E-06
# Itr = 2, residual norm = 1.2326E-12
# Time = 0.02333333333333336, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8197E-02
# Itr = 1, residual norm = 1.5445E-06
# Itr = 2, residual norm = 1.0543E-12
# Time = 0.023666666666666693, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8200E-02
# Itr = 1, residual norm = 1.5588E-06
# Itr = 2, residual norm = 1.0187E-12
# Time = 0.024000000000000028, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8203E-02
# Itr = 1, residual norm = 1.5753E-06
# Itr = 2, residual norm = 1.2198E-12
# Time = 0.024333333333333363, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8207E-02
# Itr = 1, residual norm = 1.5941E-06
# Itr = 2, residual norm = 1.1190E-12
# Time = 0.024666666666666698, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8210E-02
# Itr = 1, residual norm = 1.6155E-06
# Itr = 2, residual norm = 1.1197E-12
# Time = 0.025000000000000033, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8214E-02
# Itr = 1, residual norm = 1.6397E-06
# Itr = 2, residual norm = 1.3361E-12
# Time = 0.025333333333333367, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8217E-02
# Itr = 1, residual norm = 1.6669E-06
# Itr = 2, residual norm = 1.4704E-12
# Time = 0.025666666666666702, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8221E-02
# Itr = 1, residual norm = 1.6973E-06
# Itr = 2, residual norm = 1.4338E-12
# Time = 0.026000000000000037, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8225E-02
# Itr = 1, residual norm = 1.7313E-06
# Itr = 2, residual norm = 1.4605E-12
# Time = 0.026333333333333372, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8229E-02
# Itr = 1, residual norm = 1.7691E-06
# Itr = 2, residual norm = 1.6475E-12
# Time = 0.026666666666666707, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8233E-02
# Itr = 1, residual norm = 1.8110E-06
# Itr = 2, residual norm = 1.6876E-12
# Time = 0.02700000000000004, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8237E-02
# Itr = 1, residual norm = 1.8573E-06
# Itr = 2, residual norm = 1.5488E-12
# Time = 0.027333333333333376, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8242E-02
# Itr = 1, residual norm = 1.9084E-06
# Itr = 2, residual norm = 1.9233E-12
# Time = 0.02766666666666671, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8246E-02
# Itr = 1, residual norm = 1.9644E-06
# Itr = 2, residual norm = 1.9565E-12
# Time = 0.028000000000000046, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8251E-02
# Itr = 1, residual norm = 2.0259E-06
# Itr = 2, residual norm = 2.1695E-12
# Time = 0.02833333333333338, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8257E-02
# Itr = 1, residual norm = 2.0932E-06
# Itr = 2, residual norm = 2.2751E-12
# Time = 0.028666666666666715, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8262E-02
# Itr = 1, residual norm = 2.1666E-06
# Itr = 2, residual norm = 2.3501E-12
# Time = 0.02900000000000005, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8268E-02
# Itr = 1, residual norm = 2.2465E-06
# Itr = 2, residual norm = 2.5558E-12
# Time = 0.029333333333333385, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8274E-02
# Itr = 1, residual norm = 2.3335E-06
# Itr = 2, residual norm = 2.6063E-12
# Time = 0.02966666666666672, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8281E-02
# Itr = 1, residual norm = 2.4279E-06
# Itr = 2, residual norm = 3.0407E-12
# Time = 0.030000000000000054, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8288E-02
# Itr = 1, residual norm = 2.5302E-06
# Itr = 2, residual norm = 3.1978E-12
# Time = 0.03033333333333339, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8295E-02
# Itr = 1, residual norm = 2.6409E-06
# Itr = 2, residual norm = 3.3688E-12
# Time = 0.030666666666666724, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8303E-02
# Itr = 1, residual norm = 2.7607E-06
# Itr = 2, residual norm = 3.8086E-12
# Time = 0.03100000000000006, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8311E-02
# Itr = 1, residual norm = 2.8902E-06
# Itr = 2, residual norm = 4.0306E-12
# Time = 0.031333333333333394, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8320E-02
# Itr = 1, residual norm = 3.0301E-06
# Itr = 2, residual norm = 4.3487E-12
# Time = 0.031666666666666725, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8330E-02
# Itr = 1, residual norm = 3.1811E-06
# Itr = 2, residual norm = 4.8714E-12
# Time = 0.032000000000000056, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8341E-02
# Itr = 1, residual norm = 3.3441E-06
# Itr = 2, residual norm = 5.3253E-12
# Time = 0.03233333333333339, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8352E-02
# Itr = 1, residual norm = 3.5201E-06
# Itr = 2, residual norm = 5.6464E-12
# Time = 0.03266666666666672, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8364E-02
# Itr = 1, residual norm = 3.7104E-06
# Itr = 2, residual norm = 6.2746E-12
# Time = 0.03300000000000005, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8377E-02
# Itr = 1, residual norm = 3.9161E-06
# Itr = 2, residual norm = 7.0509E-12
# Time = 0.03333333333333338, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8391E-02
# Itr = 1, residual norm = 4.1388E-06
# Itr = 2, residual norm = 7.6340E-12
# Time = 0.03366666666666671, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8406E-02
# Itr = 1, residual norm = 4.3804E-06
# Itr = 2, residual norm = 8.3965E-12
# Time = 0.034000000000000044, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8423E-02
# Itr = 1, residual norm = 4.6431E-06
# Itr = 2, residual norm = 9.2901E-12
# Time = 0.034333333333333375, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8440E-02
# Itr = 1, residual norm = 4.9295E-06
# Itr = 2, residual norm = 1.0345E-11
# Time = 0.03466666666666671, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8460E-02
# Itr = 1, residual norm = 5.2429E-06
# Itr = 2, residual norm = 1.1505E-11
# Time = 0.03500000000000004, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8481E-02
# Itr = 1, residual norm = 5.5872E-06
# Itr = 2, residual norm = 1.2875E-11
# Time = 0.03533333333333337, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8505E-02
# Itr = 1, residual norm = 5.9674E-06
# Itr = 2, residual norm = 1.4314E-11
# Time = 0.0356666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8530E-02
# Itr = 1, residual norm = 6.3899E-06
# Itr = 2, residual norm = 1.6309E-11
# Time = 0.03600000000000003, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8559E-02
# Itr = 1, residual norm = 6.8625E-06
# Itr = 2, residual norm = 1.8171E-11
# Time = 0.03633333333333336, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8590E-02
# Itr = 1, residual norm = 7.3956E-06
# Itr = 2, residual norm = 2.0380E-11
# Time = 0.036666666666666695, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8624E-02
# Itr = 1, residual norm = 8.0022E-06
# Itr = 2, residual norm = 2.2491E-11
# Time = 0.037000000000000026, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8663E-02
# Itr = 1, residual norm = 8.6997E-06
# Itr = 2, residual norm = 2.4908E-11
# Time = 0.03733333333333336, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8706E-02
# Itr = 1, residual norm = 9.5105E-06
# Itr = 2, residual norm = 2.7281E-11
# Time = 0.03766666666666669, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8753E-02
# Itr = 1, residual norm = 1.0464E-05
# Itr = 2, residual norm = 2.9632E-11
# Time = 0.03800000000000002, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8807E-02
# Itr = 1, residual norm = 1.1600E-05
# Itr = 2, residual norm = 3.1447E-11
# Time = 0.03833333333333335, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8868E-02
# Itr = 1, residual norm = 1.2969E-05
# Itr = 2, residual norm = 3.2074E-11
# Time = 0.03866666666666668, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.8937E-02
# Itr = 1, residual norm = 1.4642E-05
# Itr = 2, residual norm = 3.1709E-11
# Time = 0.039000000000000014, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9016E-02
# Itr = 1, residual norm = 1.6710E-05
# Itr = 2, residual norm = 3.2568E-11
# Time = 0.039333333333333345, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9107E-02
# Itr = 1, residual norm = 1.9299E-05
# Itr = 2, residual norm = 4.4458E-11
# Time = 0.039666666666666676, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9212E-02
# Itr = 1, residual norm = 2.2579E-05
# Itr = 2, residual norm = 8.2899E-11
# Time = 0.04000000000000001, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9335E-02
# Itr = 1, residual norm = 2.6785E-05
# Itr = 2, residual norm = 1.6381E-10
# Time = 0.04033333333333334, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9478E-02
# Itr = 1, residual norm = 3.2245E-05
# Itr = 2, residual norm = 3.1628E-10
# Itr = 3, residual norm = 2.7299E-13
# Time = 0.04066666666666667, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9649E-02
# Itr = 1, residual norm = 3.9422E-05
# Itr = 2, residual norm = 5.9749E-10
# Itr = 3, residual norm = 1.5072E-13
# Time = 0.041, dt = 0.0003333333333333333
# Itr = 0, residual norm = 1.9853E-02
# Itr = 1, residual norm = 4.8990E-05
# Itr = 2, residual norm = 1.1198E-09
# Itr = 3, residual norm = 2.0978E-13
# Time = 0.04133333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.0100E-02
# Itr = 1, residual norm = 6.1948E-05
# Itr = 2, residual norm = 2.1094E-09
# Itr = 3, residual norm = 1.3638E-13
# Time = 0.041666666666666664, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.0403E-02
# Itr = 1, residual norm = 7.9818E-05
# Itr = 2, residual norm = 4.0392E-09
# Itr = 3, residual norm = 2.6730E-13
# Time = 0.041999999999999996, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.0780E-02
# Itr = 1, residual norm = 1.0500E-04
# Itr = 2, residual norm = 7.9489E-09
# Itr = 3, residual norm = 1.9386E-13
# Time = 0.04233333333333333, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.1257E-02
# Itr = 1, residual norm = 1.4140E-04
# Itr = 2, residual norm = 1.6266E-08
# Itr = 3, residual norm = 2.1602E-13
# Time = 0.04266666666666666, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.1872E-02
# Itr = 1, residual norm = 1.9574E-04
# Itr = 2, residual norm = 3.5101E-08
# Itr = 3, residual norm = 1.7430E-13
# Time = 0.04299999999999999, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.2683E-02
# Itr = 1, residual norm = 2.8011E-04
# Itr = 2, residual norm = 8.1331E-08
# Itr = 3, residual norm = 2.2525E-13
# Time = 0.04333333333333332, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.3784E-02
# Itr = 1, residual norm = 4.1797E-04
# Itr = 2, residual norm = 2.0757E-07
# Itr = 3, residual norm = 2.3028E-13
# Time = 0.04366666666666665, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.5330E-02
# Itr = 1, residual norm = 6.5899E-04
# Itr = 2, residual norm = 6.0672E-07
# Itr = 3, residual norm = 7.4281E-13
# Time = 0.043999999999999984, dt = 0.0003333333333333333
# Itr = 0, residual norm = 2.7603E-02
# Itr = 1, residual norm = 1.1221E-03
# Itr = 2, residual norm = 2.1709E-06
# Itr = 3, residual norm = 1.0835E-11
# Time = 0.044333333333333315, dt = 0.0003333333333333333
# Itr = 0, residual norm = 3.1165E-02
# Itr = 1, residual norm = 2.1486E-03
# Itr = 2, residual norm = 1.0853E-05
# Itr = 3, residual norm = 3.8954E-10
# Itr = 4, residual norm = 2.3287E-13
# Time = 0.044666666666666646, dt = 0.0003333333333333333
# Itr = 0, residual norm = 3.7367E-02
# Itr = 1, residual norm = 5.0569E-03
# Itr = 2, residual norm = 1.0719E-04
# Itr = 3, residual norm = 8.0249E-08
# Itr = 4, residual norm = 1.1657E-13
# Time = 0.04499999999999998, dt = 0.0003333333333333333
# Itr = 0, residual norm = 5.0867E-02
# Itr = 1, residual norm = 1.9634E-02
# Itr = 2, residual norm = 1.7258E-02
# Itr = 3, residual norm = 1.1901E-02
# Itr = 4, residual norm = 3.1620E-02
# Itr = 5, residual norm = 1.2009E-02
# Itr = 6, residual norm = 2.9965E-02
# Itr = 7, residual norm = 1.1716E-02
# Itr = 8, residual norm = 3.7685E-02
# Itr = 9, residual norm = 1.3209E-02
# Itr = 10, residual norm = 1.8151E-02
# Itr = 11, residual norm = 1.1213E-02
# Itr = 12, residual norm = 7.7130E-02
# Itr = 13, residual norm = 2.2424E-02
# Itr = 14, residual norm = 1.0820E-02
# Itr = 15, residual norm = 2.0587E+00
# Itr = 16, residual norm = 5.1740E-01
# Itr = 17, residual norm = 1.3211E-01
# Itr = 18, residual norm = 3.5969E-02
# Itr = 19, residual norm = 1.2854E-02
# Itr = 20, residual norm = 2.0167E-02
# Time = 0.044833333333333315, dt = 0.00016666666666666666
# Itr = 0, residual norm = 2.5434E-02
# Itr = 1, residual norm = 1.6453E-03
# Itr = 2, residual norm = 6.6182E-06
# Itr = 3, residual norm = 2.1618E-09
# Itr = 4, residual norm = 5.3293E-14
# Time = 0.044999999999999984, dt = 0.00016666666666666666
# Itr = 0, residual norm = 3.2884E-02
# Itr = 1, residual norm = 5.4590E-03
# Itr = 2, residual norm = 3.1926E-04
# Itr = 3, residual norm = 5.5439E-05
# Itr = 4, residual norm = 4.0740E-06
# Itr = 5, residual norm = 3.0192E-08
# Itr = 6, residual norm = 1.6853E-12
# Time = 0.045166666666666654, dt = 0.00016666666666666666
# Itr = 0, residual norm = 8.0417E-02
# Itr = 1, residual norm = 5.6556E-01
# Itr = 2, residual norm = 1.2526E-01
# Itr = 3, residual norm = 3.6749E-02
# Itr = 4, residual norm = 2.0860E-02
# Itr = 5, residual norm = 8.0740E-01
# Itr = 6, residual norm = 2.0721E-01
# Itr = 7, residual norm = 5.7640E-02
# Itr = 8, residual norm = 2.2682E-02
# Itr = 9, residual norm = 7.7566E-02
# Itr = 10, residual norm = 2.6601E-02
# Itr = 11, residual norm = 3.1711E-02
# Itr = 12, residual norm = 2.3520E-02
# Itr = 13, residual norm = 5.5371E-02
# Itr = 14, residual norm = 2.2315E-02
# Itr = 15, residual norm = 9.6314E-02
# Itr = 16, residual norm = 3.0802E-02
# Itr = 17, residual norm = 2.4254E-02
# Itr = 18, residual norm = 4.5508E-02
# Itr = 19, residual norm = 2.1145E-02
# Itr = 20, residual norm = 9.1301E-01
# Time = 0.045083333333333316, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 4.0208E-02
# Itr = 1, residual norm = 3.0083E-03
# Itr = 2, residual norm = 1.3663E-05
# Itr = 3, residual norm = 8.4412E-11
# Time = 0.04516666666666665, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 6.7084E-02
# Itr = 1, residual norm = 6.7353E-03
# Itr = 2, residual norm = 2.8740E-04
# Itr = 3, residual norm = 7.6857E-08
# Itr = 4, residual norm = 3.1151E-14
# Time = 0.04524999999999998, dt = 8.333333333333333e-05
# Itr = 0, residual norm = 1.4636E-01
# Itr = 1, residual norm = 7.9866E-02
# Itr = 2, residual norm = 1.7455E+00
# Itr = 3, residual norm = 4.7560E-01
# Itr = 4, residual norm = 1.7559E-01
# Itr = 5, residual norm = 3.5020E-01
# Itr = 6, residual norm = 1.5543E-01
# Itr = 7, residual norm = 2.4270E+00
# Itr = 8, residual norm = 6.4756E-01
# Itr = 9, residual norm = 2.1195E-01
# Itr = 10, residual norm = 1.9036E-01
# Itr = 11, residual norm = 2.4218E-01
# Itr = 12, residual norm = 1.6434E-01
# Itr = 13, residual norm = 5.9326E-01
# Itr = 14, residual norm = 1.9984E-01
# Itr = 15, residual norm = 2.1295E-01
# Itr = 16, residual norm = 1.8896E-01
# Itr = 17, residual norm = 2.4792E-01
# Itr = 18, residual norm = 1.6181E-01
# Itr = 19, residual norm = 7.3930E-01
# Itr = 20, residual norm = 2.3304E-01
# Time = 0.045208333333333316, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 7.3180E-02
# Itr = 1, residual norm = 1.5421E-03
# Itr = 2, residual norm = 1.5849E-06
# Itr = 3, residual norm = 6.7681E-13
# Time = 0.045249999999999985, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 1.0525E-01
# Itr = 1, residual norm = 4.8284E-03
# Itr = 2, residual norm = 7.8425E-06
# Itr = 3, residual norm = 2.7161E-11
# Time = 0.045291666666666654, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 1.6103E-01
# Itr = 1, residual norm = 1.9769E-02
# Itr = 2, residual norm = 5.6512E-05
# Itr = 3, residual norm = 3.3805E-09
# Itr = 4, residual norm = 3.5639E-14
# Time = 0.04533333333333332, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 2.6945E-01
# Itr = 1, residual norm = 9.9236E-02
# Itr = 2, residual norm = 1.0762E-03
# Itr = 3, residual norm = 2.3177E-06
# Itr = 4, residual norm = 4.4023E-13
# Time = 0.04537499999999999, dt = 4.1666666666666665e-05
# Itr = 0, residual norm = 5.2175E-01
# Itr = 1, residual norm = 7.6028E-01
# Itr = 2, residual norm = 2.5819E-01
# Itr = 3, residual norm = 2.9506E+00
# Itr = 4, residual norm = 9.8426E-01
# Itr = 5, residual norm = 1.1349E+00
# Itr = 6, residual norm = 1.7696E-01
# Itr = 7, residual norm = 3.9753E+01
# Itr = 8, residual norm = 9.9791E+00
# Itr = 9, residual norm = 2.3921E+00
# Itr = 10, residual norm = 3.1489E-01
# Itr = 11, residual norm = 2.7159E-01
# Itr = 12, residual norm = 8.1540E-02
# Itr = 13, residual norm = 6.7267E-02
# Itr = 14, residual norm = 4.4042E-01
# Itr = 15, residual norm = 1.2993E-01
# Itr = 16, residual norm = 6.7799E-02
# Itr = 17, residual norm = 1.0619E+01
# Itr = 18, residual norm = 2.6717E+00
# Itr = 19, residual norm = 6.8506E-01
# Itr = 20, residual norm = 1.9029E-01
# Time = 0.045354166666666654, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 2.6088E-01
# Itr = 1, residual norm = 3.1232E-02
# Itr = 2, residual norm = 1.0130E-04
# Itr = 3, residual norm = 1.8059E-09
# Time = 0.045374999999999985, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 3.5537E-01
# Itr = 1, residual norm = 6.8761E-02
# Itr = 2, residual norm = 4.6751E-04
# Itr = 3, residual norm = 8.2153E-08
# Itr = 4, residual norm = 1.3155E-14
# Time = 0.045395833333333316, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 5.0280E-01
# Itr = 1, residual norm = 1.8817E-01
# Itr = 2, residual norm = 8.1689E-03
# Itr = 3, residual norm = 4.0301E-05
# Itr = 4, residual norm = 2.5912E-10
# Time = 0.04541666666666665, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 7.6021E-01
# Itr = 1, residual norm = 1.2432E+00
# Itr = 2, residual norm = 1.4849E-01
# Itr = 3, residual norm = 2.5874E-03
# Itr = 4, residual norm = 1.3087E-06
# Itr = 5, residual norm = 1.0574E-12
# Time = 0.04543749999999998, dt = 2.0833333333333333e-05
# Itr = 0, residual norm = 1.3634E+00
# Itr = 1, residual norm = 3.7595E+00
# Itr = 2, residual norm = 8.3359E+00
# Itr = 3, residual norm = 4.6574E+00
# Itr = 4, residual norm = 1.0261E+01
# Itr = 5, residual norm = 2.9059E+00
# Itr = 6, residual norm = 6.8851E+01
# Itr = 7, residual norm = 1.7430E+01
# Itr = 8, residual norm = 3.3354E+01
# Itr = 9, residual norm = 1.3085E+01
# Itr = 10, residual norm = 2.1999E+00
# Itr = 11, residual norm = 2.6887E+02
# Itr = 12, residual norm = 6.7441E+01
# Itr = 13, residual norm = 1.4314E+01
# Itr = 14, residual norm = 5.9445E+01
# Itr = 15, residual norm = 1.5145E+01
# Itr = 16, residual norm = 3.8277E+00
# Itr = 17, residual norm = 2.5418E+00
# Itr = 18, residual norm = 1.2948E+02
# Itr = 19, residual norm = 3.3515E+01
# Itr = 20, residual norm = 8.3141E+00
# Time = 0.04542708333333331, dt = 1.0416666666666666e-05
# Itr = 0, residual norm = 6.8168E-01
# Itr = 1, residual norm = 1.2856E-01
# Itr = 2, residual norm = 7.6555E-03
# Itr = 3, residual norm = 1.6176E-05
# Itr = 4, residual norm = 6.0221E-11
# Time = 0.04543749999999998, dt = 1.0416666666666666e-05
# Itr = 0, residual norm = 9.8344E-01
# Itr = 1, residual norm = 7.2486E-01
# Itr = 2, residual norm = 8.4851E-02
# Itr = 3, residual norm = 3.7959E-04
# Itr = 4, residual norm = 2.9010E-08
# Itr = 5, residual norm = 1.5684E-14
# Time = 0.04544791666666664, dt = 1.0416666666666666e-05
# Itr = 0, residual norm = 1.9362E+00
# Itr = 1, residual norm = 5.0112E+00
# Itr = 2, residual norm = 5.6730E-01
# Itr = 3, residual norm = 7.7565E-03
# Itr = 4, residual norm = 4.0495E-05
# Itr = 5, residual norm = 1.5571E-09
# Time = 0.04545833333333331, dt = 1.0416666666666666e-05
# Itr = 0, residual norm = 3.7879E+00
# Itr = 1, residual norm = 3.6287E+01
# Itr = 2, residual norm = 7.5567E+00
# Itr = 3, residual norm = 1.2385E+01
# Itr = 4, residual norm = 1.2298E+02
# Itr = 5, residual norm = 3.2770E+01
# Itr = 6, residual norm = 1.2298E+01
# Itr = 7, residual norm = 9.1391E+00
# Itr = 8, residual norm = 4.6564E+01
# Itr = 9, residual norm = 3.6231E+01
# Itr = 10, residual norm = 3.8279E+01
# Itr = 11, residual norm = 7.5401E+02
# Itr = 12, residual norm = 2.8787E+03
# Itr = 13, residual norm = 6.3661E+02
# Itr = 14, residual norm = 1.6752E+02
# Itr = 15, residual norm = 6.9383E+02
# Itr = 16, residual norm = 2.2366E+03
# Itr = 17, residual norm = 5.1565E+04
# Itr = 18, residual norm = 1.2959E+04
# Itr = 19, residual norm = 4.9126E+03
# Itr = 20, residual norm = 4.1525E+03
# Time = 0.045453124999999976, dt = 5.208333333333333e-06
# Itr = 0, residual norm = 1.8939E+00
# Itr = 1, residual norm = 1.1037E+00
# Itr = 2, residual norm = 1.0731E+01
# Itr = 3, residual norm = 3.2104E+00
# Itr = 4, residual norm = 1.8884E+00
# Itr = 5, residual norm = 2.0498E+01
# Itr = 6, residual norm = 5.2395E+00
# Itr = 7, residual norm = 6.4805E+00
# Itr = 8, residual norm = 1.0559E+02
# Itr = 9, residual norm = 2.8010E+01
# Itr = 10, residual norm = 8.0106E+00
# Itr = 11, residual norm = 1.3605E+00
# Itr = 12, residual norm = 1.1070E-01
# Itr = 13, residual norm = 9.6423E-04
# Itr = 14, residual norm = 3.6780E-08
# Itr = 15, residual norm = 4.0713E-14
# Time = 0.04545833333333331, dt = 5.208333333333333e-06
# Itr = 0, residual norm = 3.4223E+00
# Itr = 1, residual norm = 1.5146E+00
# Itr = 2, residual norm = 2.7911E-01
# Itr = 3, residual norm = 5.2438E-03
# Itr = 4, residual norm = 2.7559E-06
# Itr = 5, residual norm = 1.1425E-12
# Time = 0.04546354166666664, dt = 5.208333333333333e-06
# Itr = 0, residual norm = 4.3291E+00
# Itr = 1, residual norm = 4.1920E+00
# Itr = 2, residual norm = 8.1440E-01
# Itr = 3, residual norm = 1.1041E-02
# Itr = 4, residual norm = 1.3921E-05
# Itr = 5, residual norm = 7.4933E-11
# Time = 0.045468749999999974, dt = 5.208333333333333e-06
# Itr = 0, residual norm = 7.2183E+00
# Itr = 1, residual norm = 3.4741E+00
# Itr = 2, residual norm = 2.7432E-01
# Itr = 3, residual norm = 4.1650E-03
# Itr = 4, residual norm = 6.3107E-07
# Itr = 5, residual norm = 1.5318E-13
# Time = 0.04547395833333331, dt = 5.208333333333333e-06
# Itr = 0, residual norm = 3.7429E+00
# Itr = 1, residual norm = 2.6264E+00
# Itr = 2, residual norm = 5.3543E-01
# Itr = 3, residual norm = 6.4796E+00
# Itr = 4, residual norm = 1.6873E+00
# Itr = 5, residual norm = 2.2558E+00
# Itr = 6, residual norm = 1.0804E+02
# Itr = 7, residual norm = 2.7146E+01
# Itr = 8, residual norm = 6.7153E+00
# Itr = 9, residual norm = 2.5707E+01
# Itr = 10, residual norm = 6.8249E+01
# Itr = 11, residual norm = 2.2905E+01
# Itr = 12, residual norm = 1.0475E+03
# Itr = 13, residual norm = 2.7023E+03
# Itr = 14, residual norm = 6.6610E+02
# Itr = 15, residual norm = 1.6119E+02
# Itr = 16, residual norm = 1.3831E+02
# Itr = 17, residual norm = 9.9509E+01
# Itr = 18, residual norm = 1.1291E+03
# Itr = 19, residual norm = 3.1022E+02
# Itr = 20, residual norm = 2.8305E+04
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 9
#       8 try:
# ----> 9     x_hat = nr_solve(residual, jacobian, x_hat, args=(t, x_hat, dt), max_itr=20)
#      10 except:
#
# Cell In[8], line 17, in nr_solve(f, df, x, atol, rtol, max_itr, args)
#      15         return x
# ---> 17 raise Exception("solve failed")
#
# Exception: solve failed
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 13
#      11     dt = dt / 2
#      12     if dt < dt_min:
# ---> 13         raise Exception("dt is too small")
#      14     continue
#      15 t = t + dt
#
# Exception: dt is too small

# %%
t
# Out:
# 0.045468749999999974
